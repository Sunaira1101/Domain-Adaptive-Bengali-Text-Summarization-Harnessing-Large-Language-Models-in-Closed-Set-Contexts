# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset I

# %%
#install dataset
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 29.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.0.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import load_dataset
from pprint import pprint

# %%
dataset = load_dataset('csebuetnlp/xlsum', 'bengali', split='test')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# xlsum.py:   0%|          | 0.00/4.55k [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/3.51M [00:00<?, ?B/s]
# 0000.parquet:   0%|          | 0.00/3.41M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8102 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1012 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1012 [00:00<?, ? examples/s]

# %%
print("Dataset length: ", len(dataset))
print("\n First item dataset[0]: ")
pprint(dataset[1])
# Out:
# Dataset length:  1012
#
#  First item dataset[0]:
# {'id': 'news-39127107',
#  'summary': 'ভারতের দক্ষিণাঞ্চলীয় রাজ্য তামিলনাডুর ব্যবসায়ীরা সেখানে '
#             'কোকা-কোলা ও পেপসি বিক্রি নিষিদ্ধ ঘোষণা করেছে।',
#  'text': 'ভারতের অন্য অঞ্চলেও কোক, পেপসি নিষিদ্ধ করার দাবি জানাচ্ছেন কর্মীরা। '
#          'স্থানীয় পণ্যের ব্যবহার নিশ্চিত করার জন্যই এই উদ্যোগ গ্রহণ করেছে '
#          'ব্যবসায়ীরা। রাজ্যের শীর্ষ দুটি ব্যবসায়ী এসোসিয়েশন এই দুটি পানীয় '
#          'নিষিদ্ধ করার প্রস্তাব করেছিল। তারই প্রেক্ষাপটে আজ বুধবার থেকে '
#          'তামিলনাডু রাজ্যে নিষিদ্ধ হলো কোকা-কোলা ও পেপসি। প্রতিষ্ঠানগুলো বলছে, '
#          'কোমল পানীয়ের প্রতিষ্ঠানগুলো নদী থেকে প্রচুর পানি ব্যবহার করে, '
#          'সেকারণে কৃষকদের জমি সেচের সময়ও ব্যাপক ভোগান্তিতে পড়তে হয়। বিশেষ '
#          'করে খরার সময় সেচে পানি সমস্যা প্রকট হয়ে দাঁড়ায়। রাজ্যের দশ '
#          'লাখেরও বেশি দোকানদার এ নিষেধাজ্ঞা মেনে চলবে বলে ধারণা করা হচ্ছে। গত '
#          "মাসে তামিলনাডুতে 'জাল্লিকাটু' নামে ঐতিহ্যবাহী ষাঁড়ের লড়াই "
#          'নিষিদ্ধের বিরুদ্ধে ব্যাপক বিক্ষোভের ঘটনা দেখে রাজ্যে পেপসি, '
#          'কোকা-কোলা নিষিদ্ধের প্রস্তাব করে শীর্ষ দুটি ব্যবসায়ী সংগঠন ফেডারেশন '
#          'অব তামিলনাডু ট্রেডার্স এসোসিয়েশন (এফটিএনটিএ) এবং তামিলনাডু '
#          "ট্রেডার্স এসোসিয়েশন। বিক্ষোভের সময় অনেকে বলছিলেন 'জাল্লিকাটু' "
#          'নিষিদ্ধ করা মানে স্থানীয় ঐতিহ্য ও সংস্কৃতিকে অবমাননা করা। "আমরা '
#          'কয়েক মাস আগে কোমল পানীয়ের বিরুদ্ধে আমাদের প্রচারণা শুরু করি, '
#          "কিন্তু যখন আমরা 'জাল্লিকাটু' নিষিদ্ধের প্রতিবাদে বিক্ষোভ শুরু করি, "
#          'কোমল পানীয়ের বিরুদ্ধে আমাদের প্রচারণাও ভিন্ন রূপ পায়"- বিবিসি '
#          "তামিল সার্ভিসকে দেয়া এক সাক্ষাৎকারে বলছিলেন এফটিএনটিএ'র প্রেসিডেন্ট "
#          'থা ভেলায়ান। "পেপসি এবং কোকা-কোলার মতো পানীয় কিন্তু আপনার '
#          'স্বাস্থ্যের জন্য ভালো নয়। কারণ এর মধ্যে বিভিন্ন ধরনের কেমিকেল থাকে '
#          'এবং অতিরিক্ত চিনি থাকে এসব পানীয়তে। আমরা ভারতীয় কোমল পানীয়ের '
#          'প্রচার চালাচ্ছি এবং ফলের জুসের বিক্রি যেন আরও বাড়ে সেই চেষ্টাও আমরা '
#          'চালাবো"-বলছিলেন ব্যবসায়ী থা ভেলায়ান। স্থানীয় ব্যবসা এবং কৃষকদের '
#          'উন্নতির কথা ভেবে সুপারমার্কেট, রেস্টুরেন্ট ও হোটেলগুলো যেন এই '
#          'নিষেধাজ্ঞা মেনে চলে সেই আহ্বানও জানিয়েছে এসোসিয়েশনগুলো। এই '
#          'নিষেধাজ্ঞার বিষয়ে পেপসি ও কোকা-কোলা প্রতিষ্ঠানের পক্ষ থেকে এখনও '
#          'কোনো মন্তব্য পাওয়া যায়নি। আরো পড়ুন: লিফট-গাড়ি নিয়ে ইন্দোনেশিয়া '
#          'যাচ্ছেন সৌদি বাদশাহ ইয়াহিয়ার জন্য রান্না বন্ধ করে দিয়েছিলেন '
#          "বাবুর্চিরা 'ভূত তাড়ানো'র নামে আগুনে পোড়ানো হলো এক নারীকে ফ্রান্সের "
#          'নির্বাচনে ওবামাকে প্রার্থী হতে আহ্বান',
#  'title': 'কোকা-কোলা, পেপসি নিষিদ্ধ হলো তামিলনাডুতে',
#  'url': 'https://www.bbc.com/bengali/news-39127107'}

# %%
pprint(len(dataset[0]['text']))
pprint(type(dataset[0]['text']))
# Out:
# 2893
# <class 'str'>

# %%
import pandas as pd

df = pd.DataFrame(dataset)

df.head()
# Out:
#               id                                        url  \
# 0  news-45155508  https://www.bbc.com/bengali/news-45155508
# 1  news-39127107  https://www.bbc.com/bengali/news-39127107
# 2  news-49141918  https://www.bbc.com/bengali/news-49141918
# 3  news-52808250  https://www.bbc.com/bengali/news-52808250
# 4  news-49047323  https://www.bbc.com/bengali/news-49047323
#
#                                                title  \
# 0  চীন ১০ লাখ উইগুর মুসলিমকে আটকে রেখেছে - জাতিসং...
# 1           কোকা-কোলা, পেপসি নিষিদ্ধ হলো তামিলনাডুতে
# 2  ডেঙ্গু পরিস্থিতি: হাসপাতালে ভর্তির দরকার না থা...
# 3  ডোনাল্ড ট্রাম্প: আমেরিকান প্রেসিডেন্টের পোস্ট ...
# 4  বাংলাদেশে বন্যার প্রকোপ: ২৪ ঘণ্টায় ডুবে যাবে ...
#
#                                              summary  \
# 0  জাতিসংঘের মানবাধিকার বিষয়ক কমিটি জেনেভাতে চীন...
# 1  ভারতের দক্ষিণাঞ্চলীয় রাজ্য তামিলনাডুর ব্যবসায...
# 2  স্বাস্থ্য অধিদপ্তরের হিসাব মতে, গত ২৪ ঘণ্টায় ...
# 3  এই প্রথম সামাজিক মাধ্যমের বিশাল প্রতিষ্ঠান টুই...
# 4  বাংলাদেশের বন্যা পূর্বাভাস এবং সতর্কীকরণ কেন্দ...
#
#                                                 text
# 0  আটক স্বজনদের আইডি কার্ড হাতে উইগুর নারীদের বিক...
# 1  ভারতের অন্য অঞ্চলেও কোক, পেপসি নিষিদ্ধ করার দা...
# 2  সোহরাওয়ার্দী হাসপাতালের চিত্র সাধারণত সেপ্টেম...
# 3  ডোনাল্ড ট্রাম্প অভিযোগ করেছেন টু্‌ইটার আমেরিকা...
# 4  বন্যার প্রকোপ ছড়িয়ে পড়ছে সারা দেশে। বাংলাদে...

# %%
df.head(10)
# Out:
#               id                                        url  \
# 0  news-54690291  https://www.bbc.com/bengali/news-54690291
# 1  news-50797621  https://www.bbc.com/bengali/news-50797621
# 2  news-46678346  https://www.bbc.com/bengali/news-46678346
# 3  news-51860832  https://www.bbc.com/bengali/news-51860832
# 4       56310420       https://www.bbc.com/bengali/56310420
# 5  news-52552857  https://www.bbc.com/bengali/news-52552857
# 6  news-55301521  https://www.bbc.com/bengali/news-55301521
# 7  news-56325380  https://www.bbc.com/bengali/news-56325380
# 8  news-53166128  https://www.bbc.com/bengali/news-53166128
# 9  news-51091547  https://www.bbc.com/bengali/news-51091547
#
#                                                title  \
# 0  দুর্গাপূজার সময়ে যেভাবে শোক পালন করেন 'মহিষাস...
# 1  রাশিয়ায় ক্ষমতার ২০ বছর যেভাবে কেটেছে ভ্লাদিম...
# 2  সংসদ নির্বাচন: বরিশালে ছয়টি আসন কিন্তু সবার দ...
# 3  সর্বকালের সর্বশ্রেষ্ঠ বাঙালি: বিবিসি বাংলার জর...
# 4  ৭ই মার্চের ভাষণ: ৫০ বছর আগে রেসকোর্স ময়দানে উ...
# 5  করোনাভাইরাস: বাংলাদেশে মধ্যবিত্তের কি সঞ্চয়ে ...
# 6  সন্তান বিক্রির ব্যবসা: কেনিয়ার কালোবাজারে ব্য...
# 7  আমেরিকার কোন প্রেসিডেন্ট সবচেয়ে বেশি অসৎ মিথ্...
# 8  করোনা ভাইরাস: যে কারণে চাহিদা বৃদ্ধির সুযোগ কা...
# 9  সিরিয়ার কুর্দি নেতা হেভরিন খালাফের হত্যাকাণ্ড...
#
#                                              summary  \
# 0  হিন্দু বাঙালীরা যে সময়ে তাদের সবথেকে বড় উৎসব...
# 1  ভ্লাদিমির পুতিন তাঁর ক্ষমতায় থাকার ২০ বছর পূর...
# 2  বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা বরিশাল এখন তুমু...
# 3  দু'হাজার চার সালে বিবিসি বাংলা একটি 'শ্রোতা জর...
# 4  'ভাষণ শুরু আগে মাথার উপর দিয়ে বিমান আর হেলিকপ...
# 5  করোনাভাইরাসের সংক্রমণ ঠেকাতে বাংলাদেশে গত ২৬শে...
# 6  বিবিসির আফ্রিকা আই অনুসন্ধান বিভাগ গত মাসে কেন...
# 7  ডোনাল্ড ট্রাম্পের বিরুদ্ধে সবচেয়ে বড় অভিযোগ ...
# 8  মার্চ মাসের শেষদিক থেকে জুনের শুরু পর্যন্ত দুই...
# 9  বিবিসির নিউজ অ্যারাবিকের তদন্তে জোরালো প্রমাণ ...
#
#                                                 text
# 0  দুর্গাপুজায় মহিষাসুর বধ্যে মধ্য দিয়ে অশুভর ও...
# 1  গত ২০ বছরে তিনি রাশিয়ার প্রেসিডেন্ট এবং প্রধা...
# 2  বরিশাল সদরে চলছে নির্বাচনী প্রচার প্রচারণা। যদ...
# 3  রবীন্দ্রনাথ ঠাকুর রবীন্দ্রনাথ ঠাকুর বাঙালির কা...
# 4  আর কুমিল্লা থেকে বাস ভাড়া করে অনেকের সাথে নিজ...
# 5  শুধু নিম্ন নয়, মধ্য আয়ের মানুষের রোজগারেও কর...
# 6  আডামা তার গ্রামে ফিরে গেছেন। তিনি বলছেন, ''জীব...
# 7  আমেরিকার সাবেক কজন প্রেসিডেন্ট কিন্তু তাদের সা...
# 8  বাংলাদেশে গত কয়েকবছর ধরে ফুডপান্ডা, হাঙ্গরি ন...
# 9  ইতালিতে বিক্ষোভকারীরা হেভরিন খালফের স্মরণে হাত...

# %%
df['text'][2]
# Out:
# 'বরিশাল সদরে চলছে নির্বাচনী প্রচার প্রচারণা। যদিও প্রায় সব আসনেই প্রচার প্রচারণা বেশি চোখে পড়ছে ক্ষমতাসীন আওয়ামী লীগ দলীয় প্রার্থীদেরই। তারপরেও আওয়ামী লীগ প্রার্থীদের পাশাপাশি আলোচনায় রয়েছেন বিএনপি বা জাতীয় ঐক্যফ্রন্ট মনোনীত প্রার্থীদের নিয়ে। এমনকি মাঠে তেমন দেখা না গেলেও আওয়ামী লীগের প্রার্থী কিংবা নেতাকর্মীরা তাদের প্রচারে বারবারই তুলে আনছেন বিএনপি মনোনীত প্রার্থীদের প্রসঙ্গ। বরিশালে ছয় আসন কিন্তু সবার দৃষ্টি সদর ও গৌরনদীতে আরও পড়তে পারেন: রাজশাহীতে নির্বাচনী পরিবেশ \'ভালো\', কিন্তু বাইরে? সাংবাদিকদের চোখে মোটরসাইকেল নিষেধাজ্ঞা হিন্দু ভোটারদের ঘিরেই নাসিরনগরে যত সমীকরণ রাজনৈতিক বিবেচনায় গুরুত্বপূর্ণ সদর আসন: বরিশাল-৫ আসনটিই জেলায় সদর আসন এবং এই অঞ্চলের রাজনীতি এ এলাকাকে কেন্দ্র করেই পরিচালিত হয়। আসনটিতে ২০০৮ সালের নির্বাচনে বিএনপির মজিবর রহমান সরওয়ার নির্বাচিত হয়েছিলেন আওয়ামী লীগের জাহিদ ফারুক শামীমকে হারিয়ে। এবারও তারা দুজনই একে অন্যের প্রতিদ্বন্দ্বী। এর আগে ৯১ ও ৯৬ সালেও বিএনপি প্রার্থী এ আসনে বিজয়ী হয়েছিলেন আর ২০১৪ সালে বিনা প্রতিদ্বন্দ্বীতায় জিতেছিলেন আওয়ামী লীগের প্রয়াত শওকত হোসেন হিরন। তার মৃত্যুর পর তার স্ত্রী জিতেছিলেন উপ নির্বাচনে। কিন্তু ২০১৪ সাল ছাড়া এ আসনে ১৯৯১ সাল থেকে পরবর্তীতে সব নির্বাচনই এখানে জমজমাট হয়েছিল। এমনকি তত্ত্বাবধায়ক সরকারের আমলে মেয়র নির্বাচনে আওয়ামী লীগ প্রার্থী যেমন জিতেছিলেন তেমনি আওয়ামী লীগ আমলে জিতেছিলেন বিএনপির মেয়র প্রার্থী। এবং সেটা সর্বশেষ মেয়র নির্বাচনে। তবে এবার পরিস্থিতি ভিন্ন। শহরের আওয়ামী লীগ প্রার্থী জাহিদ ফারুককে সমর্থনে ব্যাপক প্রচার চোখে পড়লেও বিএনপি প্রার্থী মজিবর রহমান সরওয়ারের প্রচার চোখে পড়ছে কমই। অথচ শহরেই নৌকা প্রতীকে পাশাপাশি অসংখ্য পোস্টার চোখে পড়ে ইসলামী আন্দোলনের প্রার্থী সৈয়দ মোঃ ফয়জুল করিমের। আসনটিতে আরও প্রার্থী আছেন বিপ্লবী ওয়ার্কার্স পার্টিও আব্দুস সাত্তার, এনপিপির শামিমা নাসরিন, জাতীয় পার্টির একেএম মুরতজা আবেদীন ও বাংলাদেশ জাতীয় পার্টির এইচ এম মাসুম বিল্লাহ। নির্বাচনী প্রচারণায় আওয়ামী লীগ প্রার্থী। কি বলছে আওয়ামী লীগ ও বিএনপি? মহানগর বিএনপির সহসভাপতি মহসিন মন্টু বলছেন গণ-গ্রেপ্তার আতঙ্কে গাঢাকা দিতে বাধ্য হয়েছেন তার দলের নেতাকর্মীরা। "বাধার কারণে সভা সমাবেশ করা যাচ্ছেনা। পোস্টারগুলো ছিঁড়ে ফেলা হচ্ছে। এমনকি পোস্টার লাগাতে গেলে হুমকি দেয়া হচ্ছে"। তিনি বলেন, "সেনাবাহিনী নামলে এবং লেভেল প্লেয়িং ফিল্ড হলে পরিস্থিতি পাল্টে যাবে"। তবে মহানগর আওয়ামী লীগের সিনিয়র সহ সভাপতি আফজালুল করিম বলছেন বিএনপির অভিযোগ সত্যি নয় কারণ প্রতিদিনই তাদের প্রচারণার ছবি প্রকাশিত হচ্ছে। মিস্টার করিম বলেন গ্রেফতারের বিষয়ে তাদের কোন বক্তব্য নেই কারণ এটি আইন-শৃঙ্খলা সম্পর্কিত বিষয়। "যাদের ধরা হচ্ছে তারা একাধিক মামলার আসামী"। ধানের শীষের পক্ষে চলছে প্রচারণা। আসনটির ইস্যু কি? শহীদুল ইসলাম নামে একজন দোকানী এ প্রশ্নের উত্তরে বলেন, "এখানে ইস্যু রাজনীতি"। তার মতে আসনটি বিএনপি ও আওয়ামী লীগের জন্য মর্যাদার আসন হিসেবে বিবেচিত হচ্ছে। আর সে কারণেই কেউ কাউকে ছাড় দিতে নারাজ এবার। এ আসনে ভোটারদের সাথে কথা বলে পরিস্থিতি বোঝা মুশকিল তবে অনেকেই বলছেন শহরের রাস্তাঘাট প্রশস্ত করা দরকার, বেকারত্ব অনেক তীব্র আর শিল্প কারখানা না থাকায় কর্মসংস্থান বাড়ছেনা। তবে তরুণ ভোটার অনেকের মধ্যেই ভোট সঠিক ভাবে হবে কি-না তা নিয়ে উদ্বেগ আছে। তারিন তাসনিম জুঁই নামে একজন নতুন ভোটার বলছিলেন, "এবার ভোট দিবো এবং এটি নিয়ে আমি খুবই উচ্ছ্বসিত। তাই চাই ভোটটা যেন ঠিক মতো হয়"। জান্নাতুল ফেরদৌস কানিজ বলেন, "আমরা যেন ভোট দিয়ে বলতে পারি যিনি নির্বাচিত হয়েছেন তিনি আমাদের ভোটেই হয়েছেন।" ভোটারদের অনেকেই জানিয়েছেন ভোট নিয়ে এমন উদ্বেগ আছে অনেকের মধ্যেই আর এর কারণ হল চলতি বছরেই হওয়া সিটি কর্পোরেশন নির্বাচন। যে নির্বাচনে ব্যাপক ভোট কারচুপির অভিযোগ উঠেছিল। তরুণদের একজন অপূর্ব কুমার বলছিলেন, "সিটি কর্পোরেশনের নির্বাচনের কারণেই আমরা উদ্বিগ্ন"। বরিশাল এখন তুমুল নির্বাচনী প্রচারণায় সরগরম \'ইলেকশন যেমন অওয়ার অইবে\' সদরের বাইরে জেলার যে আসনটি নিয়ে সবচেয়ে বেশি আলোচনা হচ্ছে সেটি হল বরিশাল-১। গৌরনদী ও আগৈলঝাড়া নিয়ে গঠিত এ আসনে আওয়ামী লীগের প্রার্থী সাবেক চীফ হুইপ আবুল হাসনাত আব্দুল্লাহ। মিস্টার আব্দুল্লাহর ছেলে সাদিক আব্দুল্লাহ্ই বরিশাল সিটি কর্পোরেশনের এখনকার মেয়র এবং গত জুলাইয়ের যে নির্বাচনে জিতে তিনি মেয়র হয়েছেন সে নির্বাচন নিয়েই ব্যাপক কারচুপির অভিযোগ উঠেছিল। যদিও তিনি ও আওয়ামী লীগ তা বরাবরই প্রত্যাখ্যান করেছেন। আর বিএনপির প্রার্থী সাবেক সংসদ সদস্য জহির উদ্দিন স্বপন, যিনি দলটির সংস ...

# %%
rows = df.shape[0]
rows
# Out:
# 1012

# %% [markdown]
# # Install and Imports

# %%
# !pip install sentencepiece
# !pip install transformers
# !pip install git+https://github.com/csebuetnlp/normalizer

import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

from normalizer import normalize # pip install git+https://github.com/csebuetnlp/normalizer


from transformers import XLMProphetNetForConditionalGeneration, XLMProphetNetTokenizer


from transformers import MBartForConditionalGeneration, AutoModelForSeq2SeqLM
from transformers import AlbertTokenizer, AutoTokenizer
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-wa293wd9
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-wa293wd9
#   Resolved https://github.com/csebuetnlp/normalizer to commit d405944dde5ceeacb7c2fd3245ae2a9dea5f35c9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2024.9.11)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.13)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=ff85a90bdd8d1e4613d64893d9bd96b5a919d12f3fe4d72707d80e578ad1a501
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oixlmscd/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=599bbab36ab82687aeb27c41313734f3ee5748a247cb5fa2ca8d70f2e56c9ffa
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=dc63775e3129f652ce6c45a1aac3d4704fbe8f02b769ec13c10af1a0a55c31a2
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
import torch
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### Functions

# %%
def cleanText(text2clean):
    empty_string = ""

    space = chr(32)
    flag  = 0

    for i in range(len(text2clean)):
        if text2clean[i] != "'" and text2clean[i] != "\n":
            if text2clean[i] == space and flag == 0:
                flag = 1
                empty_string = empty_string + text2clean[i]
            elif text2clean[i] != space:
                empty_string = empty_string + text2clean[i]
                flag = 0
    return empty_string

# %% [markdown]
# # Model Loading

# %% [markdown]
# ### Model Setup

# %%
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

tokenizer_path = "/content/drive/MyDrive/Colab/mT5_Tokenizer_XLSum"
model_path = "/content/drive/MyDrive/Colab/mT5_Model_XLSum"

# Step 4: Load the tokenizer and model from the specified paths
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

model.to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/2.33G [00:00<?, ?B/s]
# MT5ForConditionalGeneration(
#   (shared): Embedding(250112, 768)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 768)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#               (relative_attention_bias): Embedding(32, 12)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-11): 11 x MT5Block(
#         (layer): ModuleList(
#           (0): MT5LayerSelfAttention(
#             (SelfAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): MT5LayerCrossAttention(
#             (EncDecAttention): MT5Attention(
#               (q): Linear(in_features=768, out_features=768, bias=False)
#               (k): Linear(in_features=768, out_features=768, bias=False)
#               (v): Linear(in_features=768, out_features=768, bias=False)
#               (o): Linear(in_features=768, out_features=768, bias=False)
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): MT5LayerFF(
#             (DenseReluDense): MT5DenseGatedActDense(
#               (wi_0): Linear(in_features=768, out_features=2048, bias=False)
#               (wi_1): Linear(in_features=768, out_features=2048, bias=False)
#               (wo): Linear(in_features=2048, out_features=768, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): MT5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): MT5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=768, out_features=250112, bias=False)
# )

# %% [markdown]
# ### Run dataset over the Model

# %%
df.columns
# Out:
# Index(['id', 'url', 'title', 'summary', 'text'], dtype='object')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os

save_path = '/content/gdrive/My Drive/Colab'
os.makedirs(save_path, exist_ok=True)  # Create the directory if it doesn't exist

# %%
# Create empty DataFrame without the "title" column
genDf = pd.DataFrame(columns=["text", "givenSummary", "mT5_Test_XLSum"])

# Load over the dataset
for i in range(rows):
        article_text = normalize(df['text'][i])

        # Tokenize the input text
        input_ids = tokenizer(
            [WHITESPACE_HANDLER(article_text)],
            return_tensors="pt",
            padding="max_length",
            max_length=512,
            truncation=True
        )["input_ids"]

        # Generate the summary
        output_ids = model.generate(
            input_ids=input_ids.cuda(),
            max_length=400,
            min_length=64,
            no_repeat_ngram_size=2,
            num_beams=4
        )[0]

        # Decode the generated summary
        summary = tokenizer.decode(
            output_ids,
            skip_special_tokens=True,
            clean_up_tokenization_spaces=False
        )

        # Add the text, given summary, and generated summary to the DataFrame
        genDf.loc[i] = [df['text'][i], df['summary'][i], summary]

        # Print the generated summary for verification
        print(i, '  ', summary)

# Save the DataFrame to CSV
genDf.to_csv('/content/gdrive/My Drive/Colab/mt5_test.csv')
# Out:
# 0    জাতিসংঘের একটি মানবাধিকার সংস্থা অভিযোগ করেছে, চীনের জিনজিয়াং প্রদেশে উইগুর মুসলিমদের গণহারে ধরে বিভিন্ন বন্দীশিবিরে রূপান্তরিত করার ঘটনায় চীনকে অভিযুক্ত করা হয়েছে।
# 1    ভারতের তামিলনাডু রাজ্যে কোকা-কোলা এবং পেপসি নিষিদ্ধ করেছে ব্যবসায়ীরা। এই দুটি পানীয় নদী থেকে প্রচুর পানি ব্যবহার করে, সে কারণে কৃষকদের জমি সেচের সময়ও ব্যাপক ভোগান্তিতে পড়ে।
# 2    বাংলাদেশের রাজধানী ঢাকার বেশ কয়েকটি হাসপাতাল ঘুরে দেখেছেন বিবিসির প্রতিবেদক। সেখানে প্রতিদিনই বাড়ছে ডেঙ্গুতে আক্রান্ত রোগীর সংখ্যা। এর মধ্যে অনেক রোগী ধারণ ক্ষমতা পূর্ণ হয়ে যাওয়ায় ডাক্তারদের উপরও মানসিক চাপ তৈরি হয়েছে।
# 3    যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প অভিযোগ করেছেন সামাজিক মাধ্যম টুইটার আমেরিকার ২০২০ সালের নির্বাচনে নাক গলাচ্ছে বলে একটি বিতর্কিত পোস্ট দিয়েছেন। এর জের ধরে তিনি বলেছেন এই প্রতিষ্ঠানটি নির্বাচন গ্রহণ করতে পারেনি।
# 4    বাংলাদেশের উত্তরের চারটি জেলা আগামী ২৪ ঘণ্টার মধ্যে বন্যায় প্লাবিত হওয়ার পূর্বাভাস দিচ্ছে বন্যা পূর্বায়ক এবং সতর্কীকরণ কেন্দ্র। এসব জেলার বাসিন্দারা বলছেন, এখন পানি আর নৌকায় যাতায়াত করতে হচ্ছে।
# 5    ভারতের স্বরাষ্ট্রমন্ত্রী রাজনাথ সিং দাবি করেছেন, মাওবাদী বিদ্রোহ দমনের সমাধানে সরকারি কৌশলে বিরাট কোনও পরিবর্তন হচ্ছে না। কিন্তু ঝটিতি জাদুবলে এই সমস্যা মিটবে না, আর এরকোনও শর্টকাটও নেই।
# 6    বাংলাদেশে বিরোধীদল বিএনপি তাদের নেত্রী খালেদা জিয়ার জেলে থাকা এবং নির্বাচন নিয়ে বিদেশি কূটনীতিকদের সাথে বৈঠক করেছে। কিন্তু এতে কী উদ্দেশ্য হাসিল হচ্ছে বিএনপির?
# 7    বাংলাদেশে করোনাভাইরাস সংক্রমণের দ্বিতীয় ঢেউ আসতে পারে বলে আশঙ্কা প্রকাশ করেছেন দেশটির প্রধানমন্ত্রী শেখ হাসিনা। আর শীতের দিকে রোডম্যাপ তৈরির প্রয়োজনীয়তার কথা জানিয়েছে জাতীয় কারিগরি পরামর্শক কমিটি।
# 8    বাংলাদেশের রাজধানী ঢাকার পল্টনের বিএনপি কার্যালয়ে পুলিশের সাথে সংঘর্ষের ঘটনা ঘটেছে। বিএনপির নেতাকর্মীদের মধ্যে ধাওয়া-পাল্টা ধাওয়ার পর গাড়িতে আগুন দেয়া এবং ভাঙচুর করা হয়েছে।
# 9    বাংলাদেশে করোনাভাইরাস মহামারির কারণে আইনশৃঙ্খলা বাহিনীর সঙ্গে কথিত 'বন্দুকযুদ্ধে' নিহত হবার ঘটনা অনেকটা নিয়মিত ব্যাপার হয়ে দাঁড়িয়েছে। কিন্তু সোমবার সকালেও এই ঘটেছে।
# 10    বাংলাদেশের রাজধানী ঢাকায় শীতাতপ নিয়ন্ত্রণের যন্ত্র বা এসি বিক্রি হঠাৎ করে বেড়ে গেছে। বিক্রেতা বলছেন, এসির চাহিদা বেশি যে তারা সরবরাহ করতে পারছেন না, তাতে তাদের দামও বাড়িয়ে দিয়েছেন বিক্রেতারা।
# 11    বাংলাদেশে করোনাভাইরাসের সংক্রমণ শনাক্তের হার গত কয়েকদিনের তুলনায় কিছুটা কমে গেছে বলে জানিয়েছে স্বাস্থ্য বিভাগের একজন সাবেক কর্মকর্তার পক্ষ থেকে জানা যাচ্ছে। এর মধ্যে নিউমার্কেট ফুটওভার ব্রিজের ওপরও নতুন করে আক্রান্ত হয়ে মারা
# 12    ভারতের উত্তরপ্রদেশ রাজ্যের আগ্রা তাজমহলকে ঘিরে হিন্দু ও মুসলিমদের ঐতিহ্যকে কেন্দ্র করে যে 'তাজ মহোৎসব' আয়োজন করা হয়ে থাকে, সেই উৎসবের মূল থিম হবে রামলীলা।
# 13    বাংলাদেশের সেনাবাহিনী প্রধান জেনারেল আজিজ আহমেদ বলেছেন, যুক্তরাষ্ট্র সফরের সময় 'অফিশিয়াল কোন প্রোটোকল' ব্যবহার করা তিনি সমীচীন মনে করি না এবং সেটা অসৎ উদ্দেশ্য।
# 14    বাংলাদেশে শীতের সময় করোনাভাইরাসের প্রকোপ বাড়ার আশংকা তুলে ধরে রোডম্যাপ তৈরির পরিকল্পনা করেছে স্বাস্থ্য মন্ত্রণালয়। এর মধ্যে নানা রোগ এবং কোভিড-১৯ এই দুই ভাগে চিকিৎসার প্রস্তুতি নেয়া হয়েছে।
# 15    গত সপ্তাহে পাকিস্তানের রাজনৈতিক নেতাদের একটি সাক্ষাৎকার মাঝপথে বন্ধ করে দেওয়ার পর টিভি চ্যানেলের স্ক্রিন ও বিজ্ঞাপনের প্রচার শুরু হয়েছিল। কিন্তু এর আগে থেকেই এধরনের ঘটনা ঘটে।
# 16    বাংলাদেশে করোনাভাইরাসের টিকাদান কার্যক্রমের প্রথম ডোজ প্রদান সাময়িকভাবে বন্ধ রাখার সিদ্ধান্ত নিয়েছে সরকার। ভারতের সেরাম ইন্সটিটিউটের মাধ্যমে এই টিকাটি সংগ্রহ করা হয়েছিল।
# 17    যুক্তরাষ্ট্রের একটি বেসরকারি কোম্পানি ভার্জিন গ্যালাকটিক ঘোষণা করেছে যে তারা প্রথমবারের মতো মহাকাশে যাওয়ার জন্য তাদের স্পেস এক্স ফ্লাইটের প্রশিক্ষণ নিচ্ছেন একজন মার্কিন নাগরিক।
# 18    ইতালিতে অবৈধভাবে সন্তানদের খৎনা করানোর অভিযোগে একজন ডাক্তারের মৃত্যুর ঘটনা নিয়ে উদ্বেগ প্রকাশ করেছে দেশটির রাজধানী রোম। এই খবর পাওয়া গেছে রোমের একটি হাসপাতালে।
# 19    সিরিয়া থেকে ব্রিটেনে চলে যাওয়া বাংলাদেশী বংশোদ্ভূত শামীমা বেগম তার ব্রিটিশ নাগরিকত্ব বাতিল করতে পারেন বলে তার পারিবারিক আইনজীবী জানিয়েছেন। কিন্তু এই সিদ্ধান্ত নিয়ে তিনি আবার সে দেশে ফিরতে চান।
# 20    বাংলাদেশের রাজধানী ব্রাক্ষ্মনবাড়িয়া থেকে ঢাকায় আসা প্রিয়াঙ্কা তরফদার গত পাঁচ বছরে ট্রেনে পাথর ছুড়ে ২,০০০ বেশি জানালা-দরজা ভাঙ্গার ঘটনা ঘটেছে। কিন্তু তার জীবন কীভাবে বিপন্ন হয়ে গেলো?
# 21    ইসরায়েলের নির্বাচনে প্রধানমন্ত্রী বেনিয়ামিন নেতানিয়াহুকে ক্ষমতা থেকে বিদায় করে দিতে ভূমিকা রাখার চেষ্টা করেছেন আরব রাজনৈতিক দলগুলো। কিন্তু এবারের নির্বাচনটি এমন একটি সংঘাতের মুখে পড়েছে যার মধ্যে রক্ষণশীল মুসলিম সম্প্রদ
# 22    বাংলাদেশে ব্যাংকিং নিয়ে সরকার ঘোষিত বিধি-নিষেধের মধ্য দিয়ে আজ (বুধবার) সব তফসিলি ব্যাংকে ব্যবস্থা নিতে হবে বলে জানিয়েছে নিয়ন্ত্রক প্রতিষ্ঠান সূত্রে জানা গেছে। এর আগে থেকেই বিধিনিষেধা কার্যকর হবার কথা বলা হয়েছে।
# 23    বাংলাদেশে করোনাভাইরাস মহামারির কারণে চলমান লকডাউনের দুই মাস পর এখন পর্যন্ত প্রায় সাত কোটি মানুষকে খাদ্য সহায়তা দেয়ার কার্যক্রম শুরু হয়েছে। কিন্তু সরকারের পক্ষ থেকে এই সাহায্য দেয়া হচ্ছে।
# 24    ইস্তাম্বুলের সৌদি কনস্যুলেটের ভেতর থেকে নিহত নাগরিক জামাল খাসোগজির ঘটনা সম্পর্কে যে খবর পাওয়া গেছে, তা নিয়ে নতুন করে বিভ্রান্তি তৈরি হয়েছে বলে জানা যাচ্ছে।
# 25    ভারতের রাজধানী দিল্লি বিশ্ববিদ্যালয়ের রাষ্ট্রবিজ্ঞানের এম এ ক্লাস থেকে ছাত্রছাত্রীদের পড়তে বলা হয়েছে, এমন চারটি বইকে বাদ দেওয়ার প্রক্রিয়া শুরু করেছে ওই বিশ্ববিদ্যালয়, যা নিয়ে প্রশ্ন তুলেছেন কয়েকজন শিক্ষার্থী।
# 26    ভারতের সুপ্রিম কোর্ট তার মুসলিম স্বামী শাফিন জাহানকে ইসলামে ধর্মান্তরিত করার অনুমতি দিয়েছে। আখিলা হাদিয়া সোমবার বিকেলে দেশটির সর্বোচ্চ এজলাসে দাঁড়িয়ে সে কথার পুনরাবৃত্তি করেছেন।
# 27    উত্তর কোরিয়ার সাবেক গুপ্তচর প্রধান কিম ইয়ং-চোলকে শাস্তি হিসেবে শ্রম শিবিরে পাঠানোর খবর বেরুনোর পর তাকে আবার নিখোঁজ করা হয়েছে বলে জানাচ্ছে দেশটির সংবাদ মাধ্যম।
# 28    আপনি যদি ২০ বছর বয়সে আপনার মস্তিষ্ক প্রথমবারের মতো উদ্ভাবনী চিন্তার হটস্পটে পরিণত হয়, সেই বয়স ফেলে আসেন, তাহলে আপনাকে এমন কিছু জানানো হবে যার সঙ্গে তালিকাভুক্ত করা হয়।
# 29    ইউরোপীয় কাউন্সিলের প্রেসিডেন্ট টেরিজা মে বলেছেন ইউকে থেকে ব্রিটেনের অভিবাসীদের বের হয়ে যাওয়ার জন্য তার দেশের পার্টনারদের একটি প্রস্তাব 'লাইন বাই লাইন' পড়ে দেখা গেছে ।
# 30    ঘূর্ণিঝড় 'ফণী' বাংলাদেশের দক্ষিণ-পশ্চিমাঞ্চলের দিকে এগিয়ে যাচ্ছে বলে জানিয়েছেন আবহাওয়া ও পরিস্থিতি বিভাগের সচিব বজলুর রশীদ। শনিবার মংলায় আশ্রয়কেন্দ্রে যাওয়ার জন্য মাইকিং করা হচ্ছে।
# 31    বাংলাদেশে প্রবীণদের দেখভালের ক্ষেত্রে গৃহপরিচারিকাদের ওপর নির্ভর করতে বাধ্য হচ্ছেন পরিবারের সদস্যরা। কিন্তু এই বয়স্কদের নিরাপত্তা নিয়ে বিশেষজ্ঞরা উদ্বেগ প্রকাশ করেছেন।
# 32    বাংলাদেশ ক্রিকেট দল বিশ্বকাপের ষষ্ঠ আসরে মুখোমুখি হচ্ছে। বাংলাদেশের ওয়ানডে সিরিজের সেরা কিংবদন্তী অলরাউন্ডারদের তালিকায় ঢুকে গেছেন সাকিব আল হাসান। এই ছাড়াও তিনি এখন অস্ট্রেলিয়ার সাবেক ক্রিকেটার মাইক হাসি এবং অস্
# 33    বাংলাদেশে করোনাভাইরাস মহামারির কারণে কর্মহীন এবং হতদরিদ্র মানুষের জন্য ত্রাণ সহায়তা দেয়ার তালিকা তৈরির কাজ শেষ হওয়ার কয়েক সপ্তাহের মধ্যে শুরু হয়েছে। কিন্তু দুর্নীতির অভিযোগে দু'জন ডিলারের বিরুদ্ধে ব্যবস্থা নেয়া হয়েছে
# 34    ইন্দোনেশিয়ায় গত ১৭ই এপ্রিল অনুষ্ঠিত হওয়া প্রেসিডেন্ট নির্বাচনের সময় এবং পরবর্তী কয়েকদিনের মাথায় ৫০০ জনেরও বেশি নির্বাচনী কর্মকর্তা মারা যাওয়ার খবর পাওয়া গেছে।
# 35    করোনাভাইরাস সংক্রমণ ঠেকাতে বিভিন্ন রকম ওষুধ তৈরির চেষ্টায় আছেন ব্রিটেনের বিজ্ঞানীরা - যাতে রোগীদের দ্রুত সারিয়ে তোলা সম্ভব হতে পারে বলে ধারণা করা হচ্ছে।
# 36    তিন মাস বয়সে জ্যাকি এবং তার স্বামী জুলিয়ান একেবারেই ঘুমাতে পারেননি। কিন্তু এই সমস্যার কারণে তারা সেই কাজটি করতে পারতেন না। এটা নিয়ে বিবিসি টু'র একটি প্রতিবেদনে বলা হয়েছে।
# 37    বাংলাদেশের অন্যতম প্রধান রাজনৈতিক দল জাতীয় পার্টির মধ্যে অঙ্গীকার ভঙ্গের অভিযোগে দলের কয়েকজন এমপিকে কারণ দর্শানোর নোটিশকে কেন্দ্র করে তীব্র উত্তেজনা তৈরি হয়েছে।
# 38    নেটফ্লিক্সে অভিনয় করা একজন অভিনেত্রী মারা গেছেন। তিনি নিজের শেষকৃত্যানুষ্ঠান আয়োজনের জন্য একটি তহবিল সংগ্রহ করেছেন, কিন্তু সেটি তার ঘুমের ভেতরেই বন্ধ হয়ে গেছে।
# 39    ভারতের সুপ্রাচীন শহর বারাণসীতে হিন্দুদের কাশী বিশ্বনাথ মন্দির ও মুসলিমদের জ্ঞানবাপী মসজিদ ফিরিয়ে দেওয়ার দাবিতে উত্তরপ্রদেশের একটি আদালত এই প্রথমবারের মতো রায় দিয়েছে।
# 40    বাংলাদেশে করোনাভাইরাস মহামারির কারণে শিক্ষা প্রতিষ্ঠান বন্ধ থাকায় বাবা-মায়েরা আশঙ্কা প্রকাশ করে বলছেন, তাদের সন্তানদের মোবাইল এবং ইন্টারনেটের প্রতি আসক্তি বাড়তে পারে বলে চিকিৎসা মনোবিজ্ঞানীরা জানিয়েছেন।
# 41    স্তন ক্যান্সারের চিকিৎসায় ব্যবহৃত কিছু ভেষজ পিল রক্ত জমাট করতে বিলম্ব ঘটায়। এমনকি জিনসেং, রসুন, আদা এবং জিনিস খেলেও এর ক্ষত শুকাতে দেরি হয়।
# 42    বাংলাদেশের রাজধানী ঢাকার বাসিন্দা সাহিদা বেগম বলেছেন, পেঁয়াজের বীজ উৎপাদনের কাজ এবং এরই মধ্যে কৃষি তথ্য সার্ভিসের তদারকি শুরু হয়ে গেছে। কিন্তু এবার কিছু জমি নরম হয়েছে।
# 43    যুক্তরাজ্যে করোনাভাইরাসের যে নতুন ধরনটি শনাক্ত হয়েছে, তাতে আক্রান্ত হয়ে সাত জনের শরীরে কোভিড-১৯ রোগ পাওয়া গেছে বলে জানিয়েছেন সিলেটের সিভিল সার্জন ও স্বাস্থ্য অধিদপ্তরের কর্মকর্তারা।
# 44    বাংলাদেশে ২য় ঢেউয়ে আক্রান্ত এবং মৃত্যু বেড়েছে। সরকারি হাসপাতালের আইসিইউ বেড খালি হওয়ার কারণে এই রোগীর সংখ্যা বাড়তে শুরু করেছে বলে ধারণা পাওয়া যাচ্ছে। তবে সাধারণ মানুষের জন্য এটি এক বিরাট সংকট।
# 45    সিঙ্গাপুরের একটি কারাগারে দু'জন নান এবং কয়েদিকে মৃত্যুদণ্ড দেয়া হয়েছে। দুজনের মধ্যে একটা নতুন সম্পর্ক তৈরি হয়েছিল। কিন্তু শেষ পর্যন্ত তারা একে অপরের সাথে দেখা করেন।
# 46    বাংলাদেশে অনেকেই মানসিক স্বাস্থ্য সমস্যায় আক্রান্ত হওয়ার জন্য চিকিৎসা নিতে চান। কিন্তু এক্ষেত্রে কোন ব্যবস্থা নেয়া উচিত কিনা, তা নিয়ে নানা আলোচনা হচ্ছে, যার মধ্যে একটি হল 'কিছুটা জটিলতা'।
# 47    বাংলাদেশে মোবাইল ফোনের আঙুলের ছাপ এবং জাতীয় পরিচয়পত্রের তথ্য চুরি করার অভিযোগে পুলিশের অপরাধ তদন্ত বিভাগ (সিআইডি) অভিযান চালিয়ে ১২০০ সিম জব্দ করেছে।
# 48    মারকোস লেমা আদ্দিস আবাবায় নিজের অফিসে বসবাস করছেন। কিন্তু তার বাড়িতে কোন ইন্টারনেট সংযোগ ছিল না। সেই সঙ্গে তিনি বলছেন, এই কাজটি তার জন্য একটা বড় সমস্যা।
# 49    চীনের উনান প্রদেশের একটি রেলস্টেশনকে জীবাণুমুক্ত করেছে করোনাভাইরাস। কিন্তু বিজ্ঞানীরা এখন তাদের নাম ঘোষণা করতে যাচ্ছেন ২০১৯-এনকভ হিসেবে। এটি কী ধরণের?
# 50    বাংলাদেশের স্বাধীনতা আন্দোলনের প্রতিষ্ঠাতা রাষ্ট্রপতি শেখ মুজিবুর রহমানকে হত্যার ঘোষণা প্রচার করা হয়েছিল ১৯৭২ সালের জানুয়ারি মাসে। এরপর থেকে তাঁর নাম মুছে ফেলা হয়েছে ইতিহাস থেকেই।
# 51    বাংলাদেশে স্বর্ণের দাম গত কয়েক বছর ধরে বাড়ছে। বাজেট ঘোষণার পর থেকে এই বৃদ্ধি নিয়ে উদ্বেগ তৈরি হয়েছে মধ্যবিত্তের ওপর। বিয়ের দিন তারিখ ঠিক হয়নি এখনও।
# 52    "আমার ঋতুকালীন পরিচ্ছন্নতা বা নিরাপদ ব্যবস্থাপনা না থাকার অন্যতম কারণ সমাজের রক্ষণশীলতা।" ঢাকার কাছে মুন্সীগঞ্জের মোহাম্মদপুর এলাকার বাসিন্দা ফারজানা আক্তার বলেছেন।
# 53    আপনি কি জানেন যে বিশ্বের সবচেয়ে দামী খাবারগুলোর একটি হলদে রঙের আভা ছড়াতে পারে? কিন্তু আপনার খাদ্যের দাম এতটাই বেড়েছে যে এর বাজারজাতের কাজটি খুব সহজ।
# 54    বাংলাদেশ ক্রিকেট দলের সাবেক অধিনায়ক মুকিম চৌধুরী ঢাকা বিশ্ববিদ্যালয়ের জহুরুল হক হলে নির্যাতনের পর বিনা কারণে পুলিশের হাতে তুলে দেয়ার প্রতিবাদে রাজু ভাস্কর্যে অবস্থান নিচ্ছেন বলে জানিয়েছেন।
# 55    বাংলাদেশের একটি আদালত দুর্নীতি দমন কমিশনের কাছে মাল্টি লেভেল মার্কেটিং কোম্পানি ইউনিপেটুইউ -এর ছয়জন কর্মকর্তাকে ১৩৫১ কোটি টাকা অর্থ আত্মসাতের দায়ে কারাদণ্ড দিয়েছে।
# 56    ভারতের তথ্য ও সম্প্রচার মন্ত্রণালয় নবরাত্রির সময়ে টিভি চ্যানেলে কন্ডোমের বিজ্ঞাপন দেখানোর ওপর বিধিনিষেধ আরোপ করেছে। এ নিয়ে বিতর্ক তৈরি হয়েছে গত কয়েকদিন ধরে।
# 57    ইরানের প্রেসিডেন্ট হাসান রৌহানি বলেছেন, ইরান সমৃদ্ধ ইউরেনিয়ামের ওপর নিষেধাজ্ঞা আরোপ করেছে। ২০১৮ সালের পারমাণবিক চুক্তি থেকে তারা নিজেকে প্রত্যাহার করতে পারবে না।
# 58    অনলাইন ব্যাংকিং-এর তথ্য চুরি করে হাতিয়ে নেয়া এমন একটি বড় ধরনের সাইবার অপরাধ বিরোধী পুলিশি অভিযান ঠেকিয়েছে ইউরোপিয়ান ইউনিয়নের সবচেয়ে ক্ষুদ্র ব্যবসায়ী ও অলাভজনক প্রতিষ্ঠান।
# 59    আমাদের মস্তিস্ক আসলে কিভাবে নতুন কিছু শিখতে পারে, তা নিয়ে গবেষণা করেছেন জার্মান দার্শনিক এবং মনোবিজ্ঞানী হেরম্যান এবিংহউস। কিন্তু কোন বিষয়ের সঙ্গে পরিচয় হওয়ার প্রথম কয়েক ঘন্টার মধ্যেই আমরা ঐ বিষয়
# 60    বাংলাদেশে ১৯৭১ সালের মুক্তিযুদ্ধের সময় পাকিস্তানী বাহিনীকে সহায়তার অভিযোগে ধরে নিয়ে যাওয়া কয়েকজন রাজাকারের আনুষ্ঠানিক তালিকা প্রকাশ করা হচ্ছে বলে জানিয়েছে সরকার। এর আগেই তারা এই তথ্য জানিয়েছেন।
# 61    বাংলাদেশে পৌষসংক্রান্তি উপলক্ষে মাছ মেলায় বিক্রির জন্য একটি কাতলার দাম ১ লাখ ২০ হাজার টাকা হাঁকা হয়েছে বলে জানাচ্ছেন সিলেটের একজন ব্যবসায়ী আজিজ আহমেদ। তিনি দাবি করেছেন, এই মাছের মূল আকর্ষণ ছিল ঢাকার মেঘনা
# 62    আরব আমিরাতের প্রধানমন্ত্রী শেখ হামাদ বিন খলিফা আল নাহিয়ান ইসরায়েলের শীর্ষস্থানীয় ফুটবল ক্লাব বেইতার জেরুযালেমের অংশীদার হতে যাচ্ছেন। এই প্রথমবারের মতো যুক্তরাষ্ট্রের ট্রাম্প প্রশাসনের তত্ত্বাবধায়নে এটি চুক্তি সই করা
# 63    সামাজিক যোগাযোগমাধ্যম ফেসবুক ও ইউটিউবে সেপ্টেম্বর মাসে প্রকাশিত একটি গান, যার শিরোনাম 'বাবু খাইছো'। দিন দশেকের মধ্যে ২০ লাখেরও বেশি বার এই টার্মটি দেখা হয়ে গেছে কেবল বাংলাদেশের নেটিজেনদেরই।
# 64    অনলাইন নির্ভর এক জীবন তরুণ-তরুনীদেরকে আরো উদ্বিগ্ন, অসম্পূর্ণ ও ভীত করে তুলতে পারে, বলছে যুক্তরাষ্ট্রের একটি গবেষণা। এই তথ্য উঠে এসেছে এক নতুন জরিপে।
# 65    বাংলাদেশের রাজধানী ঢাকায় চলমান সড়ক দুর্ঘটনার পর নৌ পরিবহন মন্ত্রী মাহবুবুর রহমানের প্রতিক্রিয়া নিয়ে সামাজিক যোগাযোগ মাধ্যমে ব্যাপক সমালোচনা চলছে। কিন্তু কোন পরিবর্তন হয়নি।
# 66    ভারতে লোকসভা নির্বাচনের দিনক্ষণ ঘোষণা করতে যাচ্ছে ২৩শে মে, ভারতের ৬৬জন নির্বাচন কমিশনার দেশটির রাষ্ট্রপতি নরেন্দ্র মোদীর কাছে একটি চিঠি লিখেছেন - যাদের বেশিরভাগই সাবেক শীর্ষস্থানীয় আমলা।
# 67    বাংলাদেশ করোনাভাইরাসের টিকার ক্লিনিক্যাল ট্রায়ালের অনুমতি দিয়েছে চীন। কিন্তু ভ্যাকসিনের ক্ষেত্রে অগ্রাধিকার পাবে ডাক্তার, নার্সসহ যারা স্বাস্থ্যসেবার সঙ্গে জড়িত তারা। এ সংক্রান্ত খরচও বহন করতে হবে।
# 68    বাংলাদেশে ইন্টারনেট সেবা দানকারীদেরকে দেশের অভ্যন্তরে পরিচালিত পর্ণ সাইটের প্রবেশকারীদের নামের তালিকা করার জন্য অঙ্গীকারাবদ্ধ বলে মন্তব্য করেছেন সরকারের প্রতিমন্ত্রী তারানা হালিম। কিন্তু ঐ বক্তব্য তিনি দেননি।
# 69    ঢাকার জিগাতলা এলাকায় বাস চাপায় দুজন শিক্ষার্থীর মৃত্যু কেন্দ্র করে আন্দোলনরত ছাত্র-ছাত্রীদের সাথে পুলিশ এবং ছাত্রলীগের সংঘর্ষে বিশ্ববিদ্যালয় চত্বরে কাঁদানে গ্যাস ছোঁড়ে বিশ্ববিদ্যালয়ের ক্যাম্পাস ঢুকতে বাধা দেয়া হয়েছে।
# 70    বাংলাদেশের রাজধানী ঢাকার বোয়ালিয়া মডেল থানার প্রধান ফটকের কাছে প্রায় চার সপ্তাহ ধরে গরুর সামলাতে গিয়ে বিপাকে পড়েছে স্থানীয় পুলিশ। কিন্তু এই অবলা তিন প্রাণীকে খাবার কিনে দিতে বাধ্য হচ্ছেন মামলার তদন্ত কর্মকর্তা
# 71    যুক্তরাষ্ট্রের মুসলিম পন্ডিতরা ইসলামের দোহাই দিয়ে তাদের সামরিক পদক্ষেপকে 'নিষিদ্ধ' ঘোষণা করেছেন। এর প্রতি তারা তীব্র প্রতিক্রিয়া জানতে চান বলে জানাচ্ছেন, কিন্তু এই সংগঠনকে সমর্থন করেন না।
# 72    বাংলাদেশ প্রকৌশল বিশ্ববিদ্যালয় বা বুয়েটে একজন ছাত্রকে পিটিয়ে হত্যা করার ঘটনায় চকবাজার থানা পুলিশের পক্ষ থেকে ১৯ জনকে গ্রেফতার করেছে স্থানীয় বিভাগের কর্মকর্তারা। ঐ ছাত্রের নাম আবরার ফাহাদ।
# 73    বিশ্বকাপ ফুটবলের নকআউট পর্বের প্রথম দিনে আর্জেন্টিনা ও পর্তুগালের কাছে হেরে গেলেন ক্রিশ্চিয়ানো রোনালদো ও লিওনেল মেসি। কিন্তু শেষ ষোলেতেই দলকে জেতাতে পারেননি তাঁর কেউই।
# 74    বাংলাদেশে শিশু ধর্ষণের ঘটনায় পুলিশের গ্রেফতারের পর হত্যা করা হয়েছে সাত বছর বয়সী এক তরুণকে, কিন্তু এধরণের ঘটনাকে কেউই সেভাবে আমলে নেন না বলে মন্তব্য করেছেন আইন-শৃঙ্খলা রক্ষাকারী বাহিনী, সামাজিক কল্যাণ
# 75    বাংলাদেশের ট্যুরিস্ট ভিসার আবেদন গ্রহণের জন্য বর্তমান ব্যবস্থায় সাক্ষাতের তারিখ বা ই-টোকেন নির্ধারণ করার নির্দেশনা দিয়েছে ঢাকার ভারতীয় হাইকমিশন। নতুন প্রযুক্তির মাধ্যমে ভিসা পেতে অর্থ লেনদেন ছাড়া কোন ফ্লাইট পাওয়া যাবে
# 76    করোনাভাইরাস মহামারির কারণে ভারতের বেশ কয়েকটি রাজ্য তাদের শ্রম আইনে নানা পরিবর্তন এনেছে - যার ফলে সেখানে শ্রমিকদের অধিকার কাটছাঁট করা যাবে না, এমন কী ন্যূনতম পারিশ্রমিক দিতেও মালিকরা বাধ্য থাকবেন না।
# 77    মুম্বাই মিরর পত্রিকার একজন লেখক যৌন বিশেষজ্ঞকে জিজ্ঞেস করার জন্য একটি কলাম লিখেছেন। তার মৃত্যুর পর তার সন্তানদের পক্ষ থেকে এক বিবৃতিতে বলা হয়েছে, "তিনি এক গৌরবান্বিত জীবন যাপন করেছেন।"
# 78    বাংলাদেশের চট্টগ্রামে পুলিশ সুপার বাবুল আক্তারের স্ত্রী গুলি করে হত্যার ঘটনায় তিনজন নিহত হয়েছেন। এর মধ্যে একজন মারা গেছে বলে জানিয়েছে পুরো নগর গোয়েন্দার কর্মকর্তা মহিউদ্দিন মাহমুদ।
# 79    যুক্তরাষ্ট্রের একটি সংবাদ মাধ্যমের একজন অ্যাসাইনমেন্ট এডিটর এক নারী সাংবাদিককে অফিসের বাইরে যেতে বলেছিলেন, "আগামীকাল আমি অসুস্থ থাকব, আমার ছুটি লাগবে" এমন অভিযোগ করেছিলেন।
# 80    যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প পাকিস্তানের সাথে প্রতারণা করার অভিযোগ অস্বীকার করেছে। ইসলামাবাদ থেকে দেওয়া ১০০ কোটি ডলারের সাহায্য বাতিল করে নেওয়া হয়েছে বলে জানাচ্ছে মার্কিন পররাষ্ট্র দপ্তর।
# 81    ১৯৬৯ সালের ২৭ জুন হন্ডুরাস এবং এল সালভেডর-এর মধ্যে একটি ম্যাচ ড্র হয়েছিল। সেই ম্যাচে দুই দেশের ফুটবল ভক্তরা একে অপরকে হারিয়ে মাঠ ছাড়তে শুরু করে।
# 82    বাংলাদেশের দক্ষিণাঞ্চলীয় রাজশাহী এবং সিটি কর্পোরেশনের নির্বাচনে বিরোধী দল বিএনপির প্রার্থীরা কারচুপির অভিযোগে নির্বাচন বর্জন করেছেন বলে স্থানীয় সাংবাদিকরা জানিয়েছেন। কিন্তু তারা বলছেন, ভোট গ্রহণযোগ্যতা নিয়ে ক্ষমতাসীন দলের প্র
# 83    লিবিয়ায় কোস্টগার্ড অভিযান চালিয়ে নৌকা ভর্তি করে নাইজেরিয়ার নাগরিকদের আটক করেছে আন্তর্জাতিক অভিবাসন সংস্থা। তাদের অনেকে অবৈধভাবে ইউরোপ যাওয়ার চেষ্টা করেছিল। কিন্তু সেই পথে ব্যর্থ হয়ে তারা নিঃস্ব হয়ে পড়েছেন।
# 84    ২০১৮ সালের বিশ্বকাপ ফুটবলের সেমিফাইনাল হতে যাচ্ছে ব্রাজিল আর আর্জেন্টিনা। কিন্তু এই প্রথমবারের মতো কোনো ইউরোপীয় দল হিসেবে শেষবার এটি জেতে পারেন লিওনেল মেসি।
# 85    বিশ্বের বিভিন্ন দেশের তাপমাত্রা গত সপ্তাহে প্রায় ৫০ ডিগ্রির উপরে উঠেছে। এর মধ্যে সবচেয়ে বেশি মানুষ মারা গেছে এবং মৃতের সংখ্যাও বেড়েছে বলে জানিয়েছে বিশ্ব স্বাস্থ্য সংস্থা।
# 86    বাংলাদেশে করোনাভাইরাস সংক্রমণ ছড়িয়ে পড়ার পর থেকেই চিকিৎসা নেবার ক্ষেত্রে নানা ধরণের পদক্ষেপ নেয়া হচ্ছে বলে জানাচ্ছে দেশটির স্বাস্থ্য অধিদপ্তর। এর মধ্যে একটি হিসেব হল ঢাকার বক্ষব্যধি হাসপাতাল।
# 87    বিশ্বকাপ ক্রিস্টিয়ানো রোনালদোর বিরুদ্ধে ধর্ষণের অভিযোগ অস্বীকার করেছেন তার আইনজীবি। এর আগে তিনি বলেছেন, তাকে নির্দোষ প্রমাণ করা হবে না এবং যেকোনো ধরণের তদন্ত হলে শান্ত থাকবেন।
# 88    চীনের বার্ষিক জনসংখ্যা গত ১০ বছরের মধ্যে সবচাইতে ধীরগতিতে বাড়ার পর সেদেশের অর্থনীতির চাকা সচল রাখার জন্য প্রয়োজনীয় পদক্ষেপ নেবার আহ্বান জানিয়েছে দেশটির সরকার।
# 89    করোনাভাইরাসের সংক্রমণ ছড়িয়ে পড়া ঠেকাতে চীনের উহান শহরকে লকডাউন করা হয়েছিল এক বছর আগে। কিন্তু আজ পর্যন্ত সেই পরিস্থিতি নিয়ন্ত্রণে আনার কথা রয়েছে।
# 90    পারস্য উপসাগরের এই রক্ষণশীল রাজতন্ত্রের মাধ্যমে সৌদি আরব নারী এবং মেয়েদের ওপর সব ধরনের বৈষম্য দূর করার লক্ষ্যে জাতিসংঘেরসনদে সই করেছে দেশটির সরকার।
# 91    নিউজিল্যান্ডের প্রধানমন্ত্রী জাসিন্ডা আরডের্ন জানিয়েছেন, দেশটিতে সামরিক কায়দার সেমি-অটোমেটিকের (এমএসএসএ) এবং অ্যাসল্ট রাইফেলের ওপর নিষেধাজ্ঞা ঘোষণা করা হয়েছে। নতুন আইন অনুমোদন করেছেন তিনি।
# 92    বাংলাদেশে বিরোধী দল বিএনপির প্রেস-সচিব মারুফ কামাল খানের স্ত্রী তানিয়া খান ঢাকা মেডিকেলের বার্ন ইউনিটে অগ্নিদগ্ধ অবস্থায় মারা যাওয়ার ঘটনায় 'আত্মহত্যা'র অভিযোগ উঠেছে।
# 93    দক্ষিণ আফ্রিকায় গিয়ে একটি অনুষ্ঠানে যোগ দিয়েছিলেন হলিউড তারকা ও ক্যালিফোর্নিয়ার সাবেক গভর্নর আর্নল্ড শোয়ার্জনেগার। এ ঘটনার পর সরিয়ে নেয়া হচ্ছে তাকেকে নিয়ে।
# 94    আফগানিস্তানের কাবুলের গজনি প্রদেশের দেহ ইয়াক জেলায় একটি বিমান বিধ্বস্ত হয়েছে বলে দেশটির সরকারি কর্মকর্তারা জানিয়েছেন। কিন্তু এতে কোন তথ্য পাওয়া যায়নি। এটি তালেবানের শক্ত অবস্থান রয়েছে।
# 95    ভারতের রাজমিস্ত্রির জোগাড়ের কাজ করার উদ্দেশে সীমান্ত পেরোনোর পর আটক হওয়া তিনজন বাংলাদেশী নারী-শিশুর বিরুদ্ধে ফরেনার্স অ্যাক্টে মামলা দাবি করেছেন পশ্চিমবঙ্গ পুলিশ।
# 96    গত কয়েক বছরে কাতারের সঙ্গে কূটনৈতিক সম্পর্কে যে উন্নতি হয়েছে তার প্রকাশ ঘটেছে। তুরস্কের প্রেসিডেন্ট রেচেপ তাইয়েপ এরদোয়ান এই মন্তব্য করেছেন, 'কাতারকে মৃত্যুদণ্ড দেবার সামিল'।
# 97    ভারতে করোনাভাইরাসের টিকা সংগ্রহের কর্মসূচি একশো দিন যেতে না-যেতেই কার্যত মুখ থুবড়ে পড়েছে - আর এরই মধ্যে দেশটির আম আদমি পার্টির সরকার অভিযোগ করেছে কেন্দ্রের নির্দেশেই তাদের কোভ্যাক্সিন পাঠাতে অস্বীকার করছে।
# 98    বাংলাদেশের কক্সবাজার উপকূল থেকে রোহিঙ্গা মুসলিমদের একটি দলকে উদ্ধার করে ভাসানচরে স্থানান্তর করেছে হাতিয়া থানার ভারপ্রাপ্ত কর্মকর্তা মো. আবুল খায়ের। তবে করোনাভাইরাসের সংক্রমণ ঠেকাতে এখন তাদেরকে কোয়ারেন্টিনে রাখা হয়েছে।
# 99    বাংলাদেশের রাজধানী ঢাকার বনানীতে একটি এফআর টাওয়ারে আগুন লাগার পর আতংকিত হয়ে অনেকেই ভবনটি থেকে বেরিয়ে আসার চেষ্টা করেন। কিন্তু অগ্নি নিরাপত্তার কোন ব্যবস্থা নেই।
# 100    'প্রাণীরা কোন উপাদান নয়' এমন ফ্রান্সে সম্প্রতি একটি শ্লোগান ব্যবহার করছেন নিরামিষ ভোগীদের মধ্যে। তাদের খাদ্য তালিকায় মাংস না থাকার বিষয়টিও বেশ আলোচনা তৈরি হয়েছে।
# 101    বাংলাদেশে আশ্রয় নেয়া রোহিঙ্গাদের একটি অংশকে ভাসানচরে স্থানান্তরের সরকারি পদক্ষেপের বিরুদ্ধে অবস্থান নিয়েছে বাংলাদেশের অন্যতম প্রধান বিরোধী দল বিএনপির পক্ষ থেকে। মিয়ানমারে ফেরত পাঠানোর ক্ষেত্রে নতুন প্রতিবন্ধকতা সৃষ্টি করবে বলে অভিযোগ করেছে
# 102    বিশ্ব স্বাস্থ্য সংস্থার এক গবেষণার অংশ হিসেবে বাংলাদেশে ট্রান্সফ্যাটজনিত হৃদরোগে আক্রান্ত হয়ে মৃত্যুর প্রায় দুই তৃতীয়াংশই হয় ঢাকার মীরবাগ এলাকার বাসিন্দা মোহাম্মদ সাহা।
# 103    সৌদি আরব থেকে পালিয়ে আসা অনেক নারী এখন যুক্তরাজ্যে আশ্রয় নিচ্ছেন, কিন্তু তারা কীভাবে তাদের দেশ ছেড়ে তা নিয়ে নতুন করে আলোচনা শুরু করেছেন, এমন কিছু ধারণা করা হচ্ছে।
# 104    বাংলাদেশ ক্রিকেট বোর্ড ও সাকিব আল হাসান ভারতের বিপক্ষে সিরিজের প্রথম ম্যাচের জন্য কারণ দর্শাও নোটিস পাঠানোর পর দুপক্ষে সুরাহা হবার পর ক্রিকেটাররা অস্বস্তিকর অবস্থায় আছে বলে ধারণা করা হচ্ছে।
# 105    শ্রীলংকার উত্তর-পশ্চিমে একটি মসজিদের দরজা ভাংচুর করে ইসলামপন্থী জঙ্গীদের হামলার ঘটনায় দেশটির বিভিন্ন জায়গায় পুলিশের কারফিউ শুরু হয়েছে বলে খবর পাওয়া গেছে।
# 106    জাতিসংঘের আবহাওয়া দফতর বলছে, এ বছরের শেষ নাগাদ পৃথিবীর তাপমাত্রা তার চেয়ে এক ডিগ্রিরও বেশি বেড়ে যাবে। বিজ্ঞানীরা বলছেন, এই সংখ্যা জলবায়ুতে বিপজ্জনক পরিবর্তনের আশঙ্কা রয়েছে।
# 107    বাংলাদেশে জামায়াতে ইসলামীর সংস্কারপন্থীদের একটি নতুন রাজনৈতিক দল গঠন করার প্রক্রিয়া শুরু করেছে তাদের সেক্রেটারি জেনারেল ডা: শফিকুর রহমান। সাবেক এই নেতার নেতৃত্বে বিএনপির একজন শীর্ষস্থানীয় নেতা এবং
# 108    বাংলাদেশে এ পর্যন্ত দুই হাজার ৩০৫ জনের করোনাভাইরাসে আক্রান্ত হয়ে মৃত্যু হয়েছে বলে দেশটির স্বাস্থ্য মন্ত্রণালয় জানিয়েছে। এর মধ্যে সবচেয়ে বেশি মানুষ মারা যাচ্ছেন ফরিদপুরের বাসিন্দা কুশল চক্রবর্তী।
# 109    যুক্তরাষ্ট্রের পররাষ্ট্রমন্ত্রী হিসেবে জো বাইডেনকে বেছে নেয়া হচ্ছে শীর্ষ কূটনীতিকদের দলের পদের জন্য। কিন্তু এর মধ্যে কিছু প্রশ্ন-সমালোচনা চলছে - তা নিয়ে বিতর্ক শুরু হয়েছে।
# 110    সাহিত্যে নোবেল পুরস্কার পেয়েছেন ওমানের লেখক জোখা আলহারথি। তিনি এবং তাঁর প্রকাশনা সংস্থা স্যান্ডস্টোন প্রেস একটি নতুন প্রতিষ্ঠানের জন্য ম্যানবুকার পুরষ্কার জিতেছে।
# 111    ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদী বলেছেন, করোনাভাইরাসের মোকাবিলায় রবিবার ২২শে মার্চ সারা দেশে 'জনতা কারফিউ' চালু হবে। এই দিন মানুষ নিজে থেকেই ঘরবন্দী থাকবেন।
# 112    'শিশুদের পরিত্যাগ করা নিষিদ্ধ', এমন একটি বার্তা লিখেছেন ভেনেজুয়েলার একজন শিল্পী এরিক মেহিকানো। তিনি বলেছেন, দেশটির অর্থনীতির অব্যাহত পতন ঘটছে, যার কারণে দেশটিতে সবচেয়ে বেশি শিশুর জন্ম নিশ্চিত করতে হয়।
# 113    কমনওয়েলথের আওতাভুক্ত দেশগুলোয় মানুষের সংখ্যা প্রায় দুই কোটি। কিন্তু তারা কিভাবে রয়েছে? ১. জনসংখ্যার দিক থেকে সবচেয়ে বড় দেশগুলোর মধ্যে ভারত, মালদ্বীপ আর দক্ষিণ আফ্রিকা।
# 114    যুক্তরাষ্ট্রের রানী এলিজাবেথ টাওয়ারের সংস্কার কাজের জন্য আজ 'বিগ বেন' ঘড়ির ঘন্টাধ্বনি শেষবার বাজবে। এই ঐতিহ্যের প্রতি সম্মান জানানো হবে নতুন বছরের সূচনার মতো।
# 115    ব্রিটেনের নির্বাচন কমিশন জানিয়েছে, দেশটির সাবেক প্রধানমন্ত্রী মাহাথির মোহাম্মদ বিরোধী জোট বোরিসান ন্যাশনাল অ্যালায়েন্সের বিপুল ব্যবধানে জয়ের পর সরকার গঠনের জন্য পর্যাপ্ত আসন পেয়েছেন।
# 116    দক্ষিণ আমেরিকার রন্ডনিয়া প্রদেশে একটি ছোট শহরের এক কৃষি ফার্মের কাছে ক্যাম্পি ঢুকে পড়েছিলেন - কিন্তু তিনি দেখতে পারেননি যে সেখানে বিচ্ছিন্ন কিছু জনগোষ্ঠীর সাতে কয়েক প্রজন্ম ধরে বাইরের মানুষের যোগাযোগ হয়নি
# 117    বাংলাদেশ থেকে অবৈধভাবে বিদেশে যাওয়া শ্রমিকদের একটি বড় অংশ মৃত্যুর ঝুঁকি নিয়ে 'বডি কন্ট্রাক্ট' বা শরীর চুক্তি ছাড়া গন্তব্যে পৌঁছে দেয়া হয়। কিন্তু এর মানে কী?
# 118    বাংলাদেশের আবহাওয়া অধিদপ্তর জানিয়েছে যে ঘূর্ণিঝড় আম্পান বাংলাদেশ উপকূলের দিকে অগ্রসর হতে পারে এবং এর প্রভাব বাংলাদেশ ও ভারতের সীমান্তের সুন্দরবন অংশে বড় ধরণের পরিবর্তনের আশঙ্কা রয়েছে।
# 119    বাংলাদেশের পটুয়াখালি জেলার রাবনাবাদ চ্যানেলে নতুন একটি সমুদ্রবন্দর গড়ে তোলা হচ্ছে। বন্দরের অর্থনৈতিক বিষয়গুলো নিয়ে গবেষণা শুরু হওয়ার পর থেকেই পায়রা বন্দরটি খুবই গুরুত্বপূর্ণ।
# 120    বাংলাদেশে কুরবানির ঈদকে সামনে রেখে জাল টাকা বাজারে ছড়িয়ে দেয়ার চেষ্টা করছে বলে অভিযোগ উঠেছে ঢাকায় র ্যাপিড অ্যাকশন ব্যাংকের কর্মকর্তারা। শনিবার রাত থেকে এই তৎপরতা শুরু হয়েছে।
# 121    মার্কিন প্রেসিডেন্ট নির্বাচনের প্রচারণার সময় থেকেই ডোনাল্ড ট্রাম্পের কন্যা রয়েছেন আলোচনায়। কিন্তু ইভাঙ্কাকে কেমন দেখেছেন জাপানের নারীরা? এই প্রশ্নটি তুলেছেন অনেকেই।
# 122    যুক্তরাজ্যের রাজধানী টাওয়ার হ্যামলেটস শহরে এক খ্রিস্টান শিশুকে এক মুসলিম পরিবারের ভরণপোষণের আওতায় রাখার ঘটনার পর থেকে রেবেকা ব্রাউন বেশ কয়েকদিন ধরে সন্ত্রাসীদের সঙ্গে থাকছেন।
# 123    ইন্দোনেশিয়ার সমুদ্র সৈকত থেকে বন্ধুর সাথে মাছ ধরতে গিয়েছিলেন মুহম্মদ ইদুল, তখন একটি মাছের ধাক্কায় তার ঘাড়ে আঘাত করে তার সুঁচালো ঠোঁট ঢুকিয়ে দেয়।
# 124    ক্রাইমিয়া উপদ্বীপে ইউক্রেনের নৌবাহিনীর তিনটি জাহাজ আটকের পর দু'দেশের মধ্যে এখন তীব্র উত্তেজনা বিরাজ করছে। এই ঘটনা ঘটেছে কয়েকদিন আগে কিয়েভের দখল করা এলাকায়।
# 125    দুর্নীতি বিরোধী আন্তর্জাতিক সংস্থা ট্রান্সপারেন্সি ইন্টারন্যাশনাল বাংলাদেশ (টিআইবি) বলছে, সরকার দলীয় মন্ত্রী, জনপ্রতিনিধি এবং উচ্চপদস্থ কর্মকর্তাদের জিজ্ঞাসাবাদের আওতায় আনার ক্ষেত্রে কিন্তু খুব সক্রিয় ভূমিকা দেখাতে পারেনি।
# 126    ভারতের পশ্চিমবঙ্গের আওরঙ্গাবাদ শহরে বুকের দুধ খাওয়ানোর ছবি দিয়ে প্রেসিডেন্ট কন্যা নরেন্দ্র মোদীর নাতনি তসলিমা নাসরিনের বিরুদ্ধে প্রবল বিক্ষোভের মুখে পড়েছেন।
# 127    মার্কিন প্রেসিডেন্ট প্রার্থী জো বাইডেনের বিরুদ্ধে শিশু পাচারের অভিযোগ আনা হয়েছে। এর ফলে যুক্তরাষ্ট্রে নতুন একটি ষড়যন্ত্র তত্ত্ব তৈরি হয়েছে - যাকে বলা হয় কিউএ্যানন।
# 128    বাংলাদেশে করোনাভাইরাসে আক্রান্ত হয়ে গত ২৪ ঘণ্টায় ২২ জন মারা গেছেন। এ নিয়ে স্বাস্থ্য অধিদপ্তরের দেয়া তথ্য অনুযায়ী, মৃতের সংখ্যা ২১ জনের উপরে পৌঁছেছে বলে জানিয়েছে দেশটির স্বাস্থ্য বিভাগ।
# 129    যুক্তরাষ্ট্রে চার বছরের মেয়াদ শেষে বিদায় নিচ্ছেন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প। এরপর থেকেই তিনি হোয়াইট হাউজ ছেড়ে ওয়াশিংটনের উদ্দেশ্যে রওনা হয়েছেন। আর নতুন কংগ্রেসের নিম্নকক্ষে অভিশংসিত হলেন জো বাইডে
# 130    আফগানিস্তানের বর্তমান বাসিন্দা নারীরা যদি ঘরের বাইরে ফুটবল খেলেন, তাহলে তাদের মাথার ওপর ঝুলছে নানা ধরনের সহিংসতার হুমকি। কিন্তু কোনদিন তারা মাঠে নামবেন না।
# 131    বাংলাদেশ থেকে মালয়েশিয়ায় শ্রমিক পাঠানোর পদ্ধতি স্থগিত করেছে দেশটির সরকার। মানব পাচার এবং অভিবাসন ব্যয় বৃদ্ধি করার অভিযোগ উঠেছে রিক্রুটিং এজেন্সিগুলোর বিরুদ্ধে, সেই সঙ্গে বর্তমান ব্যবস্থায় বাংলাদেশের শ্রমিকরা পাঠাতে হবে।
# 132    ভারতের বিতর্কিত ধর্মীয় গুরু গুরমিত রাম রহিম সিং-কে ২০ বছরের সাজা দিয়েছে দেশটির একটি আদালত। কিন্তু তার অনুসারীরা সেখানে ঢুকতে বাধা দেন, এবং তাদের বিরুদ্ধে বিক্ষোভ শুরু হয়।
# 133    আমেরিকায় একটি রেস্তোঁরা ভবনের মাটির নিচের ঘর থেকে অবৈধ মাদক পাচার করা হয়েছে বলে সন্দেহ করছে কর্তৃপক্ষ। কিন্তু ওই সুড়ঙ্গটি নিয়ে যাওয়া হয়েছে সীমান্তের তলদেশ দিয়ে মেক্সিকো।
# 134    বাংলাদেশে পুলিশের বিশেষ বাহিনী র ্যাব জানিয়েছে, হেফাজতে ইসলামের সাবেক নেতা মোহাম্মদ মামুনুলকে 'শিশু বক্তা' হিসেবে বর্ণনা করেছে। তিনি বয়সে কুড়ি থেকে ত্রিশ বছরের মধ্যে নন।
# 135    ভারতীয় বেশির ভাগ বিবাহিত নারী স্বামীর নাম ধরেই ডাকতে চান। কিন্তু এই প্রথার ভিত্তিতে তারা পুরনো বৈবাহিক জীবনের ক্ষেত্রে সবচেয়ে গুরুত্বপূর্ণ একটি কারণ রয়েছে।
# 136    বাংলাদেশের কক্সবাজারের ভাসানচরে অবস্থানরত রোহিঙ্গাদের শরীরের তাপমাত্রা পরীক্ষা ও হাত ধোয়ানো শেষে তাদের ক্যাম্পে থাকার নিয়মকানুন সম্পর্কে ব্রিফ করে নৌবাহিনীর কর্মকর্তারা জানিয়েছেন।
# 137    বিজ্ঞানীরা বলছেন, প্রাকৃতিক ভূমি ধ্বংস করার ফলে মানুষের শরীরে রোগ বালাই ছড়িয়ে পড়ার ঝুঁকি অনেক বেশি। কিন্তু নতুন এক গবেষণায় এমন তথ্য উঠে এসেছে।
# 138    নতুন একটি পদ্ধতি ব্যবহার করে যাত্রীবাহী বিমানের রানওয়ে চিহ্নিত করার উদ্যোগ নিয়েছে ব্রাউনশভাইক এবং মিউনিখের গবেষকরা। এর ফলে ফ্লাইটের নিরাপত্তা ব্যবস্থা উন্নত হবে।
# 139    হিন্দুদের উৎসব দীপাবলি বা দেওয়ালীর সন্ধ্যাবেলায় বাজি পোড়ানোর বিধান নেই বলে মন্তব্য করেছেন ভারতের উত্তরপ্রদেশ রাজ্যের রাজ্যপাল রামমোহন রায়। তিনি বলেছেন, মসজিদের মিনারে তো মাইকে আজান দেওয়া হয় না।
# 140    বাংলাদেশে ক্ষমতাসীন আওয়ামী লীগের বেশ কয়েকজন নেতার বাড়ি থেকে বিপুল পরিমাণ অর্থ উদ্ধার করেছে পুলিশ। গ্রেফতারকৃতদের মধ্যে তিনজন যুবলীগ নেতা এবং তাদের সহযোগী সংগঠনের নেতারা।
# 141    মঙ্গলগ্রহের বরফের নীচে আচ্ছাদিত একটি স্থায়ী জলাধারের সন্ধান পাওয়া গেছে। বিজ্ঞানীরা বলছেন, সেখানে প্রাণের অস্তিত্ব রয়েছে কিনা তা এখনও নিশ্চিত করে বলা যাবেনা।
# 142    বিশ্বকাপের গ্রুপপর্ব থেকে খালি হাতে বিদায় নিয়েছে দক্ষিণ কোরিয়া। রাশিয়ায় খেলা দেখতে যাওয়া মেক্সিকান সমর্থকরা কোরিয়ানদের 'ভাই' বলে শ্লোগান দিয়ে তাদেরকে ধন্যবাদ জানাচ্ছেন।
# 143    বাংলাদেশে ক্ষমতাসীন আওয়ামী লীগ নেতৃত্বাধীন বাম গণতান্ত্রিক জোট সিপিবির সভাপতি ও সাধারণ সম্পাদক ওবায়দুল কাদেরর সাথে ফোনে বৈঠক করেছেন দলটির নেতা খালেকুজ্জামান।
# 144    আফগানিস্তানে এক ব্যক্তির কারাদণ্ডের মেয়াদ শেষ হওয়ার পর তাকে পাকিস্তানে ফিরিয়ে আনার চেষ্টা করা হয়েছে বলে জানাচ্ছে তাঁর পরিবারের সদস্যরা। কিন্তু তিনি নিখোঁজ হয়ে গেছেন এবং গত এক বছর ধরে সে দেশে ছুটে গিয়েছিলেন।
# 145    ভারতের রাজধানী দিল্লির একটি জনবহুল এলাকায় হোটেলে আগুন লেগে অন্তত ১৭ জনের মৃত্যু হয়েছে। হোটেলের আবাসিকদের বেশিরভাগই ঘুমিয়ে ছিলেন বলে পুলিশ জানিয়েছে। কিন্তু হোটের আগুনি নিয়ন্ত্রণে আনতে পেরেছে।
# 146    ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদী বলেছেন, সংখ্যালঘু মুসলিমদের একেবারেই বিশ্বাস করতে পারেনি দেশটির ক্ষমতাসীন দল বিজেপি। কিন্তু এই পটভূমিতে তাদের পক্ষেও ভরসা রাখা খুব কঠিন।
# 147    বাংলাদেশের খুলনার শিরোমনি এলাকায় আওয়ামী লীগের একটি কার্যালয়ে বোমা বিস্ফোরিত হয়েছে। হামলার সঙ্গে জড়িত কে বা কারা তা খতিয়ে দেখছে তদন্ত চলছে বলে দাবি করেছে পুলিশ।
# 148    মহাশূণ্যে একটি চায়ের কেটলি ভেসে বেড়াচ্ছে- এটা কি কল্পনা করতে পারেন? কিন্তু আপনি কি এটি প্রমাণ করছেন, তাহলে কার কাঁধে বর্তাবে এই টি পট বা এরকম কোন উপমাটি?
# 149    বাংলাদেশের বিপক্ষে ওয়েস্ট ইন্ডিজকে হারানোর পর থেকেই বেশ কয়েকটি প্রশংসা ও হতাশা প্রকাশ করেছেন সাবেক ক্রিকেটার ও বর্তমান ধারাভাষ্যকাররা। যার মধ্যে রয়েছে দুইটি তালিকা।
# 150    ইংল্যান্ডের বিপক্ষে ম্যাচে বাংলাদেশের কোচ হয়ে নিজেকে কী করে শান্ত রাখবেন স্টিভ রোডস? বিবিসি বাংলার একটি 'শ্রোতা জরিপ'-এর আয়োজন করেছে টিভি অনুষ্ঠান। এই প্রতিবেদনে বলা হচ্ছে, বাংলাদেশ ক্রিকেটের গূরুত্বপূর্ণ চরিত্র
# 151    ভারতের প্রধানমন্ত্রী রামমোহন চট্টোপাধ্যায়ের নির্দেশ অনুযায়ী পৃথিবীকে একটু নিরাপত্তা দেয়া উচিত, যদি আমরা সত্যি ক্রন্দনরত মানুষের পাশে দাঁড়াতে পারতাম। কিন্তু এই না পারার বিষাদ অনুভূতিই যেন বেশি করে সংবাদ মাধ্যমে উঠে
# 152    চীনের কর্তৃপক্ষ ইন্টারনেট ব্যবহারকারীদের বিরুদ্ধে অভিযোগ করেছে তারা ওয়েবো, উইচ্যাট এবং বাইদু তিয়েবা-এর সঙ্গে কঠোর নজরদারি চালু করছে। এই তদন্তের জন্য চীন সরকার একটি নতুন ব্যবস্থা নিয়েছে।
# 153    আল্লাহর প্রতি অসৌজন্যমূলক মন্তব্য করার অভিযোগে দশ বছরের কারাদণ্ড পাওয়া নাইজেরিয়ার এক কিশোরকে ক্ষমা করে দেবার জন্য বিশ্বের বিভিন্ন দেশের স্বেচ্ছাসেবী দেশটির বিরুদ্ধে আবেদন করেছেন।
# 154    ফ্রান্সে সন্ত্রাসী হামলার ঘটনার পর সিঙ্গাপুরের কর্তৃপক্ষ নিরাপত্তা পরিস্থিতির অবনতি করেছে বলে জানিয়েছে দেশটির সংবাদমাধ্যম দ্য স্ট্রেইটস টাইমস। এর আগে ঢাকায় আটকে থাকা ১২জন বাংলাদেশিকে বহিষ্কার করা হয়েছে।
# 155    বাংলাদেশের প্রধানমন্ত্রী শেখ হাসিনা সমালোচনার ক্ষুরধার জবাব দেওয়া যার সহজাত, তার এই মৌনতা অনেককেই অবাক করেছে। শনিবার সচিবালয়ে গিয়ে দুর্নীতি এবং মাদক সমস্যা নিয়ে তার মনোভাব স্পষ্ট করেছেন।
# 156    অক্সফোর্ডের সেন্ট হিউ কলেজ কর্তৃপক্ষ জানিয়েছে, মিয়ামারের নেত্রী অং সান সু চির প্রতিকৃতি একটি 'নিরাপদ স্থানে' সরিয়ে নেওয়া হয়েছে। এর মধ্যে চিত্রকর্ম বসানো হবে জাপানি।
# 157    উনিবিংশ শতাব্দীর শুরুতে মার্কিন যুক্তরাষ্ট্র আর চীনের মধ্যে উত্তেজনা তৈরি হয়েছিল। সে সময় ওয়াশিংটন আর বেইজিং একে অপর একটি যুদ্ধে জড়িয়ে পড়েছিল - যার ফলে বিশ্বের সবচেয়ে বড় দুই পরাশক্তি চীন।
# 158    বাংলাদেশের উপকূলীয় জেলা ভোলার বোরহানউদ্দিনে ফেসবুকে ইসলামের নবীকে নিয়ে কটুক্তি করে দেয়া কথিত পোস্টকে ঘিরে বিক্ষোভকারীদের সঙ্গে পুলিশের সংঘর্ষে অন্তত ২৪ জন নিহত হয়েছে।
# 159    পৃথিবীর বেশিরভাগ দেশে বাতাসের মাধ্যমে করোনাভাইরাস সংক্রমণের বিষয়টি উড়িয়ে দেয়া যায় না বলে অভিযোগ করেছে বিশ্ব স্বাস্থ্য সংস্থা। কিন্তু বিজ্ঞানীরা বলছেন, এই বিষয়টিকে তারা স্বীকার করে নিতে চান না।
# 160    যুক্তরাষ্ট্রের একটি রেসিপি বক্স সরবরাহকারী প্রতিষ্ঠান গৌস্তো - যার নাম টিমো বোলড্ট। সেখানে রান্না-বান্নার সকল উপাদান আগে-ভাগেই পরিমাপ করে কেটে-কুটে গুছিয়ে রাখা হয়।
# 161    বিশ্বের বিভিন্ন দেশে তরুণদের মধ্যে স্মার্ট ফোনে সময় কাটাচ্ছেন খুব বেশি। কিন্তু প্রযুক্তি সংস্থগুলো বলছে তারা অ্যান্ড্রয়েড ব্যবহারকারী যারা সঙ্গে কথা বলেছে তারা চায় ঠিক উল্টোটা।
# 162    ভারতের পুজোতে দেশি গরুর দুধের রঙ একটু হলদে হয়ে গেছে, এমন একটি মন্তব্য নিয়ে ফেসবুকে ব্যাপক আলোচনা-বিতর্ক শুরু হয়েছে। এরপর অনেকে বলছেন, 'সোনাদানা যদি পাই'।
# 163    করাচির স্টক এক্সচেঞ্জে গত জুন মাসে যেসব জঙ্গী হামলা হয়েছে তার সবগুলোর পেছনে ভারতের হাত আছে বলে পাকিস্তানের পররাষ্ট্রমন্ত্রী শাহ মাহমুদ কুরেশি দাবি করেছেন। কিন্তু সেই অভিযোগ অস্বীকার করার পর সে দেশ এই দাবির সমর্থন জানিয়েছে।
# 164    বাংলাদেশে নিরাপদ সড়কের দাবিতে ছাত্র-ছাত্রীদের বিক্ষুব্ধ আন্দোলনের সময় সামাজিক মাধ্যমে গুজব ছড়ানোর অভিযোগে বিভিন্ন বিশ্ববিদ্যালয়ের প্রায় শ'খানেক শিক্ষার্থী জামিন পেয়েছেন বলে জানিয়েছে আদালত।
# 165    ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদী গোটা দেশ জুড়ে নাগরিকদের তালিকা তৈরির অভিযান নিয়ে আবারও চরম বিভ্রান্তি ও অনিশ্চয়তা দেখা দিয়েছে। কিন্তু আসামে এই প্রক্রিয়া সম্পন্ন করতে বাধ্য হয়েছেন তিনি।
# 166    বাংলাদেশে সড়ক নিরাপত্তা নিশ্চিত করতে ট্রাফিক সপ্তাহের মেয়াদ আরও তিন দিন বাড়ানো হয়েছে। এই কর্মসূচীতে লাইসেন্স না থাকা, রুট পারমিট, ফিটনেসের অভাবসহ কয়েক হাজার অভিযোগের প্রেক্ষাপটে ৫০ জনকে গ্রেফতার করা হয়েছে
# 167    সোশ্যাল মিডিয়া মাধ্যম টুইটার ভারতের পার্লামেন্টারি প্যানেলের শুনানিতে হাজির হতে পারবে না বলে জানিয়েছে দেশটির তথ্য ও প্রযুক্তি মন্ত্রণালয়ের একজন শীর্ষ কর্মকর্তার বিরুদ্ধে তীব্র আক্রমণ চলছে।
# 168    নেটোর সাথে বর্তমান শীতল সম্পর্ক বেশ কয়েক বছর ধরে খারাপের দিকে যাচ্ছে। রাশিয়া এবং সোভিয়েত ইউনিয়নের মধ্যে সবচেয়ে গুরুত্বপূর্ণ তিনটি দেশকে সদস্যপদ দিয়েছে।
# 169    দ্বিতীয় বিশ্বযুদ্ধের পর ইতালি জুড়ে করোনাভাইরাসের বিস্তার ঠেকাতে মানুষের চলাচলের ওপর বিধিনিষেধ আরোপ করা হয়েছে। এরপর থেকে ইটালির নগরীগুলো এখন পুলিশের কাছে।
# 170    বাংলাদেশের ঢাকার একটি সরকারি স্কুলের বাংলা সাহিত্য সংগ্রাহক গোকুল চন্দ্র দাস তার ব্যক্তিগত বই সংগ্রহশালা গড়ে তোলার জন্য ১৫ লাখ টাকা জরিমানা করেছেন। এই লাইব্রেরির রক্ষণাবেক্ষণ খরচ সামলাতে পারছেন না তিনি।
# 171    ভারতে যৌন হয়রানির অভিযোগের মুখে সরকারি দায়িত্ব থেকে পদত্যাগ করেছেন ভারতীয় সংবাদপত্রের সম্পাদক এম জে আকবর। কিন্তু তিনি এখন তাঁর বিরুদ্ধে বেশ কজন নারী সাংবাদিককে তুলেছিলেন।
# 172    বাংলাদেশে লালমনিরহাটে একজনকে পিটিয়ে ও আগুনে পুড়িয়ে হত্যার পর কুমিল্লার মুরাদনগরে হিন্দুদের কয়েকটি বাড়িতে ভাঙচুর এবং অগ্নিসংযোগের ঘটনা ঘটেছে গত রোববার।
# 173    মিয়ানমার থেকে বাংলাদেশে পালিয়ে আসা রোহিঙ্গাদের ফিরিয়ে নেয়ার জন্য একটি যৌথ কমিটি গঠনের প্রস্তাব দিয়েছেন বাংলাদেশের স্বরাষ্ট্রমন্ত্রী মোহাম্মদ আবদুল হামিদ। এর আগে মিয়ানমারের সেনাবাহিনীর সদস্যরা এখানে থাকেন।
# 174    বাংলাদেশে ১৯৭১ সালে হত্যাকাণ্ডের শিকার বুদ্ধিজীবীদের সংখ্যা ১১শ ১১ জনে দাঁড়িয়েছে। কিন্তু ইতিহাসবিদরা বলছেন, তাদের সবাইকে স্মরণ করা উচিৎ। এমনকি স্বীকৃতির ক্ষেত্রে বিভেদ বাড়ছে।
# 175    কোভিড-১৯ ভাইরাসে আক্রান্ত হলে কৃষ্ণাঙ্গদের তুলনায় দক্ষিণ এশীয়দের মারা যাবার ঝুঁকি সবচেয়ে বেশি। কিন্তু এক জরিপে দেখা গেছে, ডায়াবেটিস ও হৃদরোগের ক্ষেত্রে এই হার শ্বেতাঙ্গদের চেয়ে বড়।
# 176    উনিশ'শ বাষট্টি সালে গালওয়ান পোস্ট থেকে চীনের সৈন্য অবশেষে পিছু হঠে - ভারতের ইতিহাসে সেই অভিজ্ঞতা অনেকটা নতুন করে ভাইরাল হয়ে উঠেছে ।
# 177    বাংলাদেশে যুদ্ধাপরাধের দায়ে ফাঁসির দণ্ডপ্রাপ্ত জামায়াতে সাবেক সহকারী মহাসচিব আব্দুল কাদের মোল্লাকে 'শহীদ' উল্লেখ করে দৈনিক সংগ্রামের সম্পাদক ও প্রকাশক আবুল আসাদকে শারীরিক হেনস্থার পর পুলিশের হাতে তুলে দেয়া হয়েছে
# 178    ঢাকার আশুলিয়ায় কথিত জঙ্গি সংগঠন 'নব্য জেএমবি'-এর প্রধান হিসেবে দাবি করা সারোয়ার জাহানকে কেন্দ্র করে পুলিশের কাউন্টার টেরোরিজম ইউনিটের একজন কর্মকর্তা নাকচ করে দিয়েছেন।
# 179    বাংলাদেশের টি টোয়েন্টি ক্রিকেটে মুস্তাফিজুর রহমানের ক্যারিয়ারের সবচেয়ে বড় ধাক্কা ছিল ২০১৬ সালের ইনজুরি ও সার্জারি। ২০১৯ সালে পাকিস্তানের সাথে তৃতীয় ম্যাচটি শুরু হয়েছিল।
# 180    এ বছরের প্রথম পূর্ণিমা এবং চন্দ্রগ্রহণ সোমবার দেখতে পাবেন বিশ্বের বিভিন্ন অঞ্চল থেকে। যার রং হবে 'সুপার ব্লাড উল্ফ মুন'। এ নিয়ে অনেক আগ্রহ দেখা গেছে।
# 181    করোনাভাইরাসের মহামারি প্রথম ছড়িয়েছে যে চীন থেকে, তাদের প্রতিবেশি ভিয়েতনাম কীভাবে নিজেকে এভাবে সুরক্ষিত রাখলো? জনস্বাস্থ্য বিশেষজ্ঞরা এমন একটি দেশকে বর্ণনা করেছেন।
# 182    রোহিঙ্গা শরণার্থীদের প্রত্যাবাসন নিশ্চিত করতে মিয়ানমারের ভূমিকায় বাংলাদেশ ক্ষোভ প্রকাশ করেছে। বাংলাদেশের পররাষ্ট্র প্রতিমন্ত্রী শাহরিয়ার আলম এবং জাতিসংঘের দুটো সংস্থার সাথে দ্বিপাক্ষিক প্রচেষ্টায় আস্থা হারাচ্ছেন তারা।
# 183    নবজাতক শিশুদের ন্যাপি পরিবর্তন করার জন্য তাদের বাবা-মা'য়েদের সাথে কাজ করতে হয়। কিন্তু অনেকেই হয়তো এটা করেন না, কারণ সন্তানের জন্মের প্রথম ছয় মাসের মধ্যেই তারা তাদেরকে অনুমতি নিতে পারবেন।
# 184    ২০১৬ সালে ঢাকায় হোলি আর্টিজান রেস্তোঁরায় হামলার ঘটনার পর থেকে আইনশৃঙ্খলা রক্ষাকারী বাহিনী ধারাবাহিক অভিযান চালিয়ে যাচ্ছে জঙ্গি তৎপরতার বিরুদ্ধে। এর মধ্যে একজন বাংলাদেশি বংশোদ্ভূত কানাডিয়ান নাগরিককে গ্রেপ্ত
# 185    ফেসবুক, গুগল, ইউটিউব ইত্যাদির বাংলাদেশে অর্জিত আয়কে করের আওতার মধ্যে আনতে হবে বলে সরকারের নতুন বাজেট প্রস্তাব অনুমোদন করেছেন অর্থমন্ত্রী আবুল মাল আবদুল মুহিত ।
# 186    নিখোঁজ হয়ে যাওয়া অস্ট্রেলিয়ার এক শিশুকে খুঁজতে বের করে তাকে সাবদানে আগলে রেখেছিল একজন কুকুর। কিন্তু এরকম এক ব্যক্তিকে বিশেষ সম্মান দেয়া হয়েছে পুলিশের পক্ষ থেকে।
# 187    বাংলাদেশের পররাষ্ট্র মন্ত্রী এ কে আবদুল মোমেন বলেছেন আমেরিকা বাংলাদেশকে প্রায় ১ কোটি ৬০ লাখ ডোজ অ্যাস্ট্রাজেনেকা ভ্যাকসিন দেবার সিদ্ধান্ত ঘোষণা করেছে। কিন্তু টিকার রপ্তানি অনুমোদন করা অনেক সময় নিচ্ছে।
# 188    বাংলাদেশের রাজধানী ঢাকায় বাসের চাপায় নিহত শিক্ষার্থী আবরার আহম্মেদ চৌধুরীর সহপাঠীরা বলছেন, "প্রশাসন কিছুই করছে না। এখনও প্রতিশ্রুতি সব প্রশাসনে জমে আছে। কিন্তু প্রতি শ্রেণীর মানুষের মধ্যে মার খেলাম।"
# 189    বাংলাদেশে ফেসবুক অ্যাকাউন্ট হ্যাক করে নবী মোহাম্মদকে নিয়ে মেসেঞ্জারে পোস্ট দেয় হ্যাকাররা, এর পর সোশ্যাল মিডিয়ায় ব্যাপক আলোচনা শুরু হয়েছে। কিন্তু কীভাবে সতর্ক থাকতে হবে?
# 190    বাংলাদেশে চাকরিতে কোটা সংস্কারের দাবিতে আন্দোলনরত ঢাকা বিশ্ববিদ্যালয়ের ছাত্রছাত্রীদের মধ্যে সোমবার রাতভর সংঘর্ষে অন্তত ১০ জন নিহত হয়েছেন। এর বেশিরভাগই তারা শাহবাগ এলাকায় অবস্থান নিয়েছেন।
# 191    যুক্তরাষ্ট্রে মৃত্যুদণ্ডের শাস্তি কার্যকর করার প্রক্রিয়া পুনরায় শুরু করেছে দেশটির কেন্দ্রীয় সরকার। কিন্তু নতুন করে এই প্রথম রায় দেওয়া হয়েছে। সেখানে এখন পর্যন্ত পাঁচজনের মৃতদেহ স্থগিত করা হচ্ছে।
# 192    মিয়ানমারের রাখাইন প্রদেশে হামলার ঘটনায় মংদু থেকে পালিয়ে যাওয়া রোহিঙ্গাদের একাংশ 'বাঙালি সন্ত্রাসী'দের ব্যাপারে সরকার জনগণ এবং বিদেশী নাগরিকদের সাবধান থাকতে বলেছে।
# 193    দুর্নীতির মামলায় সাজাপ্রাপ্ত বিএনপি চেয়ারপার্সন খালেদা জিয়া নির্বাচনে অংশ নিতে পারবেন না বলে জানিয়েছেন দলটির কেন্দ্রীয় নেতা-কর্মী-সমর্থক ও বিশ্লেষকরা। কিন্তু এ নিয়ে হতাশা ও ক্ষোভ তৈরি হয়েছে।
# 194    যুক্তরাষ্ট্রের টেক্সাস রাজ্যের দুইটি শহরের ওপর দিয়ে বয়ে গেছে হারিকেন 'হার্ভে'। এরইমধ্যে ছিন্নভিন্ন সেখানকার বাসিন্দাদের ঘর উপকূলে আঘাত হানার পর এই ঝড় দূর্বল হয়ে পরিণত হয়েছে মৌসুমি ঝড়ে।
# 195    চীনের উহান শহরে করোনাভাইরাসের প্রাদুর্ভাব শুরু হওয়ার পর থেকে সেখানকার সড়ক পরিবহনের ব্যবস্থা বন্ধ হয়ে গেছে। এর মধ্যে স্বাস্থ্যকর্মীরা বিনামূল্যে সেবা দিয়েছেন এবং তাদের কাজে আনা নেয়া হয়েছে।
# 196    বাংলাদেশে বিরোধী দল বিএনপি'র ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমান বলেছেন, "আপনারা গণতন্ত্রের বিপক্ষে দাঁড়াবেন না। জনগণের বুকে গুলি চালাবেননা। নির্বাচন কমিশনের কাছে আপত্তি জানিয়েছে আওয়ামী লীগ।"
# 197    ব্রিটেনের নির্বাচনের ফলাফল বিশ্লেষণ করেছেন রিটা চক্রবর্তী। প্রযুক্তির সাহায্যে বিবিসি টেলিভিশনে প্রকাশিত প্রতিবেদনগুলো ইংরেজিতে লেখা হয়েছে। এটি 'অটোমেটেড জার্নালিজম' বা যান্ত্রিক উপায়ে সাংবাদিকতার বিষয়ে পরীক্ষা-
# 198    নিউজিল্যান্ডের বিপক্ষে তিন ম্যাচের টেস্ট সিরিজ খেলার সুবিধার কথা জানিয়েছেন বাংলাদেশ জাতীয় ক্রিকেট দলের সাবেক অধিনায়ক নাজমুল আবেদীন ফাহিম। বিপিএলে শারীরিক ধকল নিয়ে তিনি এই সিরিজে জোর দিয়েছেন।
# 199    কুমিল্লার একটি আদালত কক্ষে ছুরি হাতে এক ব্যক্তিকে হত্যা করেছে একজন আসামি। পুলিশ বলছে, এই ঘটনায় দুই আসামির মধ্যে পূর্ব বিরোধ ছিল বলে প্রাথমিক ধারণা করা হচ্ছে।
# 200    বাংলাদেশে করোনাভাইরাস সংক্রমণ ঠেকাতে স্বাস্থ্য অধিদফতর চিকিৎসক ও সেবাকর্মীদের বিতরণ করা সুরক্ষা সরঞ্জাম (পিপিই) নিয়ে উদ্বেগ তৈরি করেছে বলে জানাচ্ছে সরকারের কর্মকর্তারা।
# 201    যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প বৃহস্পতিবার পোল্যান্ডে জি-২০ সম্মেলনের আনুষ্ঠানিক বৈঠকে 'সন্ত্রাসবাদ ও চরমপন্থা' নিয়ে হুঁশিয়ারি বার্তা দিবেন। এর আগে তাঁর বক্তব্যের কথা বলেছেন তিনি।
# 202    আফগানিস্তানের তালেবান জঙ্গিরা বহুবিবাহে বহুবিবাহ নিষিদ্ধ করার এক ডিক্রি জারি করেছে - যাতে বৈধ বিবাহ উৎসবে পুরুষরা চারটি বিয়ে করতে পারেন। কিন্তু এই বিয়ের জন্য কমান্ডারদের অধিক অর্থ খরচ করা হচ্ছে।
# 203    করোনাভাইরাসের নতুন একটি জাত যুক্তরাজ্য থেকে আসা যাত্রীদের সঙ্গে সংস্পর্শে আসার কারণ খুঁজে পাওয়া গেছে। এটি আরো দ্রুত ছড়িয়ে পড়তে পারে বলে আশঙ্কা করা হচ্ছে।
# 204    বাংলাদেশে জামায়াতে ইসলামীর কেন্দ্রীয় নেতা ব্যারিস্টার রাজ্জাকের পদত্যাগ এবং দল থেকে বহিষ্কারের ঘোষণা দলের ভেতর তরুণ প্রজন্মের অনেকেই তাদের ভূমিকা স্পষ্ট করে সামনে এগুনোর পক্ষে উদগ্রীব।
# 205    চীন থেকে আমদানি পণ্যের ওপর যুক্তরাষ্ট্রের শুল্ক বসানোর পর, চীনের অর্থনীতি নিয়ে দুই দেশের মধ্যে বাণিজ্য যুদ্ধ শুরু হয়েছে। কিন্তু এর সঙ্গে যোগ দিয়েছেন মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প।
# 206    বাংলাদেশে বিরোধী দল বিএনপি অভিযোগ করেছে যে, সরকার গণতন্ত্রের অনুপস্থিতিতে পদ্ধতিগতভাবে রাষ্ট্রযন্ত্রকে ব্যবহার করে মানবাধিকার লঙ্ঘন করছে এবং এর ফলে দেশে সব ধরণের অপরাধ ঘটেছে।
# 207    এক গবেষণায় দেখা গেছে ভেড়া মানুষের মত মুখ চেনার ক্ষমতা রাখে। বিজ্ঞানীরা বলছেন, এই পরীক্ষায় তারা নিশ্চিত হয়েছেন যে, যে ব্যক্তিদের সঙ্গে সে পরিচিত হয়েছে তাকে সে ঠিক ভাবে চিনতে পারে।
# 208    বাংলাদেশে একটি স্কুলের প্রধান শিক্ষক পদ্মা সেতুর শরীরের ওপর দিয়ে হেটে যাওয়ার ঘটনা নিয়ে সামাজিক যোগাযোগ মাধ্যমে ব্যাপক আলোচনা শুরু হয়েছে। কিন্তু এরকম ঘটনাটি ঘটেছে ঢাকায়।
# 209    বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা মহেশখালীর কালারমারছড়া ইউনিয়নে অস্ত্র তৈরির বিপুল পরিমাণ সরঞ্জামসহ দুই ব্যক্তিকে গ্রেপ্তার করেছে আইনশৃঙ্খলা রক্ষাকারী বাহিনী (র ্যাব)।
# 210    বাংলাদেশে গার্মেন্ট কারখানায় নিরাপত্তার ঘাটতি সংশোধনের চেষ্টা করছে দুটি পোশাক সংস্থা আ্যাকর্ড এবং অ্যালায়েন্স - এমন দাবি করে একটি গবেষণায় বলা হচ্ছে, সরকারের পরিদর্শন ও নজরদারি ব্যবস্থা এখনো দুর্বল।
# 211    বাংলাদেশের প্রধানমন্ত্রী শেখ হাসিনা বলেছেন, গ্রীক দেবীর যে ভাস্কর্যকে ন্যায়বিচারের প্রতীক হিসেবে দেখা হয় তারই আদালত প্রাঙ্গণ থেকে সরানোর জন্য তিনি প্রধান বিচারপতির সঙ্গে কথা বলবেন।
# 212    নতুন একটি গবেষণায় বলা হচ্ছে, সকালে নাস্তা খেলেই যে শরীরের ওজন স্বাস্থ্যসম্মত পর্যায়ে রাখা যাবে, তার প্রমাণ নেই। কিন্তু বিজ্ঞানীরা বলছেন, সকালের নাস্তার সাথে আপনার স্বাস্থ্যের উন্নতি হতে পারে।
# 213    বাংলাদেশের সুপ্রিম কোর্ট ভবন থেকে তিনজন বিচারপতির বিরুদ্ধে অসদাচরণের অভিযোগের তদন্ত শুরু হয়েছে বলে জানিয়েছে দেশটির হাইকোর্টের একজন কর্মকর্তা। এর মধ্যে এই সাবেক প্রধান বিচারক সালমা মাসুদ চৌধুরীও রয়েছেন।
# 214    বাংলাদেশের জাহাঙ্গীরনগর উপজেলায় একটি ছয়তলা মসজিদ ভেঙ্গে ফেলার কাজ শুরু হয়েছে। গবেষকরা বলছেন, এটি নবাবদের পৃষ্ঠপোষকতায় তৈরি হয়েছে এবং প্রত্নতাত্ত্বিক নিদর্শন হিসেবে স্বীকৃত হয়নি।
# 215    বাংলাদেশে কোটা সংস্কারের দাবীতে আন্দোলনের জের ধরে আটক হওয়া শীর্ষস্থানীয় নেতাদের জামিনে মুক্তির নমনীয়তা দেখানোর পর আবার তাদের প্রতি সরকারি কৌসুলিরা তীব্র প্রতিক্রিয়া জানিয়েছেন।
# 216    বাংলাদেশে ফেনীর সোনাগাজীতে মাদ্রাসা ছাত্রী নুসরাত জাহানকে হত্যার ঘটনার দ্রুত বিচার চাওয়ার দাবি জানিয়েছে তার পরিবারের সদস্যরা। এর আগে ঢাকায় বাংলা বর্ষবরণের অনুষ্ঠানে প্রতিবাদ জানানো হয়েছিলো।
# 217    ভারতের সাবেক প্রধানমন্ত্রী নভজোত সিধুর সঙ্গে পাকিস্তানি সেনাপ্রধানের একটি ছবি সামনে আসার পর থেকেই সোশ্যাল মিডিয়াতে তিনিকে আক্রমণের মুখে পড়তে হচ্ছে বলে মন্তব্য করছেন অনেকে।
# 218    মার্কিন যুক্তরাষ্ট্রের টেক্সাসে একটি অভিবাসী বন্দিশালায় ৪০ জন পুরুষ এবং নারীকে বন্দী করে রাখা হয়েছে। তদন্তকারীরা বলছেন, এ ধরনের পরিস্থিতি টাইম বোমার মতো বলে তারা মনে করছেন।
# 219    টিয়াগো সিলভিয়েরা নামের এক কিশোর তার সঙ্গে এক জোড়া জাগুয়ারের ছবি সামাজিক মাধ্যমে ভাইরাল হওয়ার পর তা নিয়ে ব্যাপক আলোচনা শুরু হয়েছে। কিন্তু এটা কিছুটা ভুয়া?
# 220    বাংলাদেশের উত্তরাঞ্চলীয় জেলা জামালগঞ্জে একটি ওয়াজ মাহফিল স্থগিত করেছে আয়োজকরা। স্থানীয় প্রশাসন দু'পক্ষকে নিয়েই বৈঠকে বসেছিলো দুই পক্ষ, যাদের মধ্যে ছিলো হেফাজত ইসলামের নেতা মামুনুল হক।
# 221    ভারতীয় উপমহাদেশে যেভাবে গণপিটুনিতে হত্যার অনুশীলন চলছে, তা নিয়ে আমার মনে হচ্ছে - 'এই মৃত্যু উপত্যকা' ই ভারতের ইতিহাসে সবচেয়ে গুরুত্বপূর্ণ একটি বিষয়।
# 222    যুদ্ধের হৃদয় বিদারক এবং ভয়ংকর দৃশ্যের ছবিগুলো ফোর্বস অ্যাপসের মাধ্যমে প্রকাশিত হওয়ার পর বাংলাদেশের দু'জন কার্টুনিস্ট ও ইলিয়াস হুসেইনসহ কয়েকজন প্রতিষ্ঠাতা নিয়ে আলোচনা শুরু হয়েছে।
# 223    আফগানিস্তানে তালেবানের সঙ্গে শান্তি আলোচনার জন্য ভারতের শীর্ষ নেতা ড: আবদুল্লাহ্ বিন সালমান দিল্লি সফরে যাচ্ছেন - যার মধ্যে একটি বড় উৎসব হচ্ছে দোহায় গত ১২ই সেপ্টেম্বর থেকে শুরু হয়ে থাকা ঐতিহাসিক
# 224    ১৯৯৬ সালে আরব বিশ্বের প্রথম ২৪ ঘণ্টার সংবাদ চ্যানেল হিসেবে আত্মপ্রকাশ করেছিল আল জাজিরা। তবে এই গণমাধ্যমের ভবিষ্যৎ নিয়ে প্রশ্ন উঠতে শুরু করেছে নানা দেশের কূটনৈতিক সংকট।
# 225    ভারতের পশ্চিমবঙ্গ রাজ্যের রসগোল্লার উৎপত্তির পর বিরিয়ানি নিয়ে লড়াই বেঁধেছে দুই রাজ্যে। যার মধ্যে একটি হল বঙ্গু বা বাঁশের খোলে দমে রান্না করা।
# 226    আমেরিকানদের নেতৃত্বে যে কোয়ালিশন সিরিয়ায় বিরোধীদের সাহায্য করছে, তারা রোববার ঘোষণা করেছে যে তুরস্কের দক্ষিণ সীমান্ত লাগোয়া অঞ্চলে একটি বাহিনী তৈরির প্রক্রিয়া শুরু করেছেন।
# 227    পাকিস্তানে আটক হওয়া ভারতীয় বিমান বাহিনীর ফাইটার পাইলট আভিনন্দন ভার্থামানকে ফেরত দেওয়ার অনুরোধ জানিয়েছে ভারতের পররাষ্ট্র মন্ত্রণালয়। কিন্তু তিনি এখন আলোচনার কেন্দ্রে পরিণত হয়েছেন।
# 228    ইরানের রাজধানী তেহরানে বিক্ষোভকারীদের ওপর নিরাপত্তা বাহিনীর গুলি চালানোর ঘটনায় মৃতের সংখ্যা একশর বেশি। জাতিসংঘ কর্মকর্তারা বলছেন, এসব সহিংসতায় প্রাণ হারিয়েছে অন্তত ৩০ জন।
# 229    ভারতের পশ্চিমবঙ্গ রাজ্যের মুখ্যমন্ত্রী পবন কুমার চামলিং দাবি করেছেন, তিস্তা নদীর পরিবেশ বা বাস্তুতন্ত্রের কোনও ক্ষতি হয়নি বললেই চলে। কিন্তু ওই যুক্তি দেখিয়ে তিনি তীব্র সমালোচনার মুখে পড়েছেন।
# 230    নতুন এক গবেষণায় দেখা গেছে, সারা বিশ্বে কুকুরের সংখ্যা বাড়ছে। বিজ্ঞানীরা বলছেন, এই হুমকির কারণে প্রায় এক ডজন পাখী এবং পশুর প্রজাতি বিলীন হয়ে যাচ্ছে - যার বেশিরভাগই স্তন্যপায়ী জীবজন্তু।
# 231    ভারতের নাগরিকত্ব সংশোধনী আইনের বিরুদ্ধে ইউরোপীয় পার্লামেন্টের একটি প্রস্তাব তীব্র প্রতিবাদ ও সমালোচনার মুখে পড়তে শুরু করেছে - যাকে তারা 'অবিলম্বে' বর্ণনা করেছেন।
# 232    বাংলাদেশে করোনাভাইরাসের সংক্রমণ ঠেকাতে সরকারের নতুন বিধি-নিষেধের বিরুদ্ধে বিক্ষোভের প্রেক্ষাপটে ঢাকায় যানবাহন চলাচলের ক্ষেত্রে অ্যাপ-ভিত্তিক মোটরসাইকেলের জনপ্রিয়তা পেয়েছে।
# 233    ভারতের উত্তর-পূর্বাঞ্চলীয় রাজ্য ছত্তিশগড়ে নিরাপত্তা বাহিনীর অভিযানে মাওবাদী নেতা মাদভি হিডমা নামে একজন ব্যক্তি নিহত হবার পর সেখানে তীব্র আতঙ্ক তৈরি হয়েছে।
# 234    তুরস্কের এক মা বলছেন, তার গর্ভধারণ শুরু হওয়ার পর থেকেই তিনি মা হতে চলেছেন। কিন্তু তার ধারণা ছিল না যে, তাড়াতাড়ি সন্তান জন্ম দেয়া হয়েছে। সেই সময়ে তার পেটে ব্যথা হয়েছিল।
# 235    ভারত এবং পাকিস্তানের মধ্যে কাশ্মীর ইস্যুতে নতুন করে উত্তেজনা তৈরি হয়েছে। দুই দেশের শিল্পীদের গাওয়া একটি গান সামাজিক যোগাযোগ মাধ্যমে ভাইরাল হওয়ার পর এ নিয়ে উদ্যোক্তারা বলছেন, 'শান্তির পক্ষে দাড়াই'।
# 236    ইরানের রাজনীতিবিদ মোহাম্মাদ রাসুলফ বার্লিন চলচ্চিত্র উৎসবে প্রথম পুরষ্কার গ্রহণ করেছেন। কিন্তু তার দেশত্যাগ নিয়ে কর্তৃপক্ষের আপত্তির কারণে তিনি নিষেধাজ্ঞা দেয়ার পর এই পুরস্কার জিতেছেন ।
# 237    ২০১৯ সালের অর্থনীতিতে নোবেল পুরষ্কার পেয়েছেন অভিজিৎ বিনায়ক ব্যানার্জি ও আব্দুল লতিফ জামিল পোভার্টি অ্যাকশন ল্যাব প্রতিষ্ঠাতা এসথার ডুফলো, সেন্ধিল মুল্লাইনাথান।
# 238    যুক্তরাষ্ট্রের বাকিংহাম রাজ পরিবারের পক্ষ থেকে জানানো হয়েছে যে রাণী প্রিন্স চার্লস এবং তার স্ত্রী কর্নওয়ালের ডাচেস ক্যামিলা করোনাভাইরাসের কারণে চিকিৎসাধীন রয়েছেন বলে জানা গেছে।
# 239    বাংলাদেশে বিরোধীদল বিএনপির নেতারা বলছেন, ২০১৮ সালের নির্বাচনে অনিয়ম বা কারচুপির অভিযোগ নিয়ে মামলা করার পক্ষে তারা এখনও কোনো সিদ্ধান্ত নিচ্ছেননি। দলটির সিনিয়র যুগ্ম মহাসচিব রুহুল কবির রিজভী এই তথ্য জানিয়েছেন
# 240    করোনাভাইরাসের সংক্রমণ ঠেকাতে ভিটামিন ডি ক্যাপসুল ব্যবহার করা নিয়ে ইন্টারনেটে ব্যাপকভাবে বিভ্রান্তি তৈরি হয়েছে। কিন্তু এসব ভুয়া তথ্য প্রচারের কারণে অনলাইনে ব্যাপারটা ভিন্ন চেহারা নেয়।
# 241    পৃথিবীতে প্রথমবারের মতো কম্পিউটার ব্যবহার করা হয়েছিল ১৯৬৬ সালে। এই যন্ত্রটির নাম ছিল 'পাসওয়ার্ড সিস্টেম' এবং এর মূল উদ্ভাবন হল টাইম শেয়ারিং।
# 242    বাংলাদেশের একটি গবেষণা বলছে ২০১২-১৩ থেকে ২০১৬-১৭ অর্থবছরের বার্ষিক উন্নয়ন কর্মসূচির অর্থ বরাদ্দের মধ্যে ঢাকা এবং চট্টগ্রামের পর যে জেলাটি রয়েছে সেটা হল গোপালগঞ্জ।
# 243    বাংলাদেশের ময়মনসিংহ শহরে এক মুসলিম অটোচালকের সাথে তার 'অবৈধ প্রেম'-এর অভিযোগে আদিবাসী এক নারীকে অপদস্থ করেছে পুলিশ। এরপর রায় দেয়া হয়েছে, তারা তাদের শুদ্ধ করার জন্য শুদ্ধাচার অনুষ্ঠান পালন করবে।
# 244    বাংলাদেশে করোনাভাইরাস টেস্টের ফলাফল ভুল হওয়ার কারণে অন্যান্য দেশের মতো বাংলাদেশেও ম্যাস টেস্টে করা হচ্ছে। কিন্তু এ ধরণের পরীক্ষায় কখনও শতভাগ নমুনা পাওয়া যায় না বলে জানিয়েছেন সংক্রামক ব্যাধি বিশেষজ্ঞরা।
# 245    ভারতের পশ্চিমবঙ্গ রাজ্যে সীমান্তের দুটি স্থল বন্দরে মালপত্র ওঠানামা বন্ধ হয়ে গেলেও কেন্দ্রকে টলাতে পারেনি রাজ্য সরকার। কিন্তু এখনও ওই স্থলবন্দর খুলে দিতে রাজি নন রাজ্যের স্বরাষ্ট্রসচিব।
# 246    গুরু রাম রহিম সিং ভারতে 'সব হিরোর বাপ' হিসেবে পরিচিত। কিন্তু ভারতের রাজধানী হরিয়ানার সিরসায় তাঁর প্রকাণ্ড হাই-টেক আশ্রম নিয়ে তীব্র বিতর্ক চলছে।
# 247    বাংলাদেশে নিরাপদ সড়কের দাবিতে আন্দোলনকারী ইলিয়াস কাঞ্চনের বিরুদ্ধে মানহানির অভিযোগে আদালত তাকে ক্ষতিপূরণ দেয়ার সুনির্দিষ্ট নির্দেশ দিয়েছে। তিনি বলেছেন, এখন নিজে গিয়ে বা আইনজীবীর মাধ্যমে ব্যাখ্যা দিতে হবে।
# 248    যুক্তরাষ্ট্রের নতুন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প ২০১৫ সালে একটি বাণিজ্য চুক্তি স্বাক্ষর করার পর এই প্রথম নির্বাচনী প্রতিশ্রুতি পূরণ করেছেন। কিন্তু তিনি এখন থেকে ন্যায় সঙ্গত ভাবে ব্যবসা করছেন না।
# 249    বিবিসির প্রভাবশালী নারীর তালিকা প্রকাশ করেছে 'রিভেঞ্জ পর্ন'। কিন্তু এর বিরুদ্ধে লড়াইয়ে নেমেছেন এমন এক নারী - যিনি একসময় ছিলেন ডিজনি তারকা, এবং এখন নিজেই পর্ণ ছবির একজন পরিচালক।
# 250    বাংলাদেশ প্রিমিয়ার লিগের নিলামের দিন বিদেশি ক্রিকেটারদের সাথে সরাসরি চুক্তি করার কথা ঘোষণা করেছে ঢাকার চিটাগং ভাইকিংস ও কুমিল্লা ভিক্টোরিয়ান্স। কিন্তু আগেই নিশ্চিত করা হয়েছিল এই ড্রাফট।
# 251    লালমনিরহাটের পাটগ্রামে বৃহস্পতিবার গণপিটুনিতে নিহত হওয়া শহীদুন নবী জুয়েলের স্ত্রী এবং তার দুই সন্তানকে নিয়ে সামাজিক যোগাযোগ মাধ্যমে ব্যাপক আলোচনা চলছে।
# 252    মালয়েশিয়ায় ৯২ বছর বয়সী সাবেক প্রধানমন্ত্রী মাহাথির মোহাম্মদ আবার ক্ষমতায় থাকতে যাচ্ছেন। এর আগে তিনি ক্ষমতা গ্রহণের জন্য দল থেকে বহিষ্কৃত হবার পর এই প্রথম ব্যক্তি হলেন।
# ...
# 927    জেরুজালেমে এক মাস ধরে চলতে থাকা তীব্র উত্তেজনার পর ইহুদী আর ফিলিস্তিনিদের মধ্যে এক ধরনের সহিংসতা শুরু হয়েছে। গত কয়েকদিনে এই দুই দেশের সংঘর্ষে অন্তত ৪০ জন নিহত হয়েছে এবং ৫০ জনেরও বেশি প্রাণ হারিয়েছে।
# 928    অভিনেত্রী কঙ্গনা রানাওয়াতের বাড়ি ও লাগোয়া অফিস ভেঙে ফেলার ঘটনায় মুম্বাই কর্পোরেশনের মুখ্যমন্ত্রী উদ্ভব ঠাকরের উদ্দেশ্যে একটি ভিডিও টুইট করার পর রাজ্যের রাজনীতিতে তীব্র উত্তেজনা তৈরি হয়েছে।
# 929    গত কয়েকদিনে ভারতে ছেলেধরা বা গণপিটুনি ছড়ানোর ঘটনার পর হোয়াটসঅ্যাপ বলছে, তারা ভারতের জন্য 'আতঙ্কিত' এবং সরকারের সঙ্গে হাত মিলিয়ে এই চ্যালেঞ্জের মোকাবিলা করতে প্রস্তুত।
# 930    ব্রিটিশ রাজপরিবারে নতুন যে শিশু যোগ হয়েছে তার নাম চূড়ান্ত করার জন্যে প্রিন্স হ্যারি ও তার স্ত্রী মেগান মের্কেলের হাতে আছে ছ'সপ্তাহ। কিন্তু কী ধরনের নাম রাখা হবে সেটা নিয়ে অনেকেই বিস্ময় দেখেন।
# 931    নিখোঁজ থাকা লন্ডনের তিন কিশোরী আমিরা আবাস, শামীমা বেগম এবং খাদিজা সুলতানা ইসলামিক স্টেটের সাথে যোগ দিতে সিরিয়ায় যাবার পরিকল্পনা করছে বলে আশংকা করা হচ্ছে।
# 932    বাংলাদেশ ক্রিকেট বোর্ডের সভাপতি নাজমুল হাসান বলেছেন, মাশরাফি বিন মর্তুজা টি-টোয়েন্টি দলে ফিরতে চান কিন্তু এই সিরিজেই তাকে ফিরিয়ে নিতে বাধ্য করা হয়নি। এর আগে ২০১৭ সালে বাংলাদেশের ওয়ানডে দলের অধিনায়ক খালেদ মাহম
# 933    আরিফুল ইসলাম ২০১৬ সালের ফেব্রুয়ারি মাসের ১২ তারিখ। ঢাকার কাছে তার বাড়ি থেকে ৭/৮ কিলোমিটার দূরে ধরলা ব্রিজ পার হয়ে তাকে নিয়ে যাওয়া হচ্ছিল। তখন তিনি বলছিলেন, আইনশৃঙ্খলা বাহিনীর যেসব সদস্য ছিল তাদের হাত পা
# 934    ইংল্যান্ডের কেমব্রিজ বিশ্ববিদ্যালয়ের ওয়েবসাইটে ১৯৬৬ সালে লেখা একটি পিএইচডি থিসিস প্রকাশের পর এত লোক এটি দেখেননি যে তারা পৃথিবীর কোথাও এমন ঘটনা ঘটেনি।
# 935    করোনাভাইরাসে আক্রান্ত হওয়ার পর চীনের নববর্ষের ছুটি তিনদিন বাড়ানোর সিদ্ধান্ত নিয়েছে দেশটির স্বাস্থ্য বিভাগ। নতুন এ ভাইরাসের সংক্রমণ ঠেকাতে যুক্তরাষ্ট্রসহ বেশ কয়েকটি দেশ তাদের নাগরিকদের চীন ভ্রমণ না করার নির্দেশনা দিয়েছে
# 936    তুরস্কের সরকার একটি নতুন আইন প্রবর্তন করেছে যেখানে সামাজিক যোগাযোগ নেটওয়ার্কে ব্যবহৃত তথ্য সংরক্ষিত রাখার জন্য বিশাল প্রযুক্তি সংস্থাগুলোকে জরিমানা করা হতে পারে এবং তাদের ডেটা সরবরাহ ব্যবস্থার ওপর প্রভাব পড়বে।
# 937    বাংলাদেশের পররাষ্ট্রমন্ত্রী এ কে আব্দুল মোমেন বলেছেন, ভারতের ক্ষমতাসীন বিজেপি বিতর্কিত নাগরিকত্ব যাচাই-বাছাইয়ের বিষয়টি নিয়ে তিনি মনে করেন না। কিন্তু এ বিষয়ে বাংলাদেশে কোন কিছু করবে না বলে তাকে বলছেন না সরকার।
# 938    বরগুনায় প্রকাশ্যে কুপিয়ে মারা যাওয়া রিফাতকে জেলার পুলিশ সুপার মো: মারুফ হোসেন বলেছেন, এ ঘটনায় অভিযুক্তদের খুঁজে বের করে সর্বোচ্চ শাস্তির ব্যবস্থা করা হবে বলে তিনি জানিয়েছেন।
# 939    সুয়েজ খালে আটকে পড়া এভার গিভেন নামের একটি জাহাজকে আংশিক ভাসানো সম্ভব হয়েছে। সোমবার (২৯ মার্চ) এর মধ্যে সেটি আবার চলাচল করতে সক্ষম হবে বলে জানিয়েছে মিশরের কর্তৃপক্ষ।
# 940    নিউজিল্যান্ডের প্রেসিডেন্ট মুহাম্মার গাদ্দাফির সমর্থকদের বিরুদ্ধে ফরাসী জঙ্গী বিমান হামলার ঘটনায় তিনি নিহত হবার পর সেখানকার বিরোধী যোদ্ধাদের সঙ্গে তার লড়াই শুরু হয়েছে৻
# 941    আমেরিকার প্রেসিডেন্ট ডোনাল্ড ট্রাম্প এবং উত্তর কোরিয়ার নেতা কিম জং আনের মধ্যে একটি বৈঠকের দুদিন আগেই সিঙ্গাপুর গেছেন দুই দেশের শীর্ষস্থানীয় রাজনৈতিক নেতাদের।
# 942    প্যারিসে এক নারীর সাথে যৌন হয়রানির অভিযোগে ব্রাজিল ফুটবল তারকা নেইমারের বিরুদ্ধে আন্তর্জাতিক ক্রিকেট দলের একজন খেলোয়াড়কে গ্রেপ্তার করেছে দেশটির ফরাসি পুলিশ। নাইজেরিয়ার এই ক্রিকেটার এখনো নিখোঁজ রয়েছেন।
# 943    ভারতের পার্লামেন্টে একটি বিল পাস হওয়ার পর দেশের সব মানুষের ডিএনএ-র প্রোফাইলিং করা হবে না বলে মনে করছে সরকার। কিন্তু মন্ত্রী হর্ষ বর্ধন বলছেন, তারা আদৌ তা নয়।
# 944    চীনের বিজ্ঞানীরা বলছেন, নরম দেহের যেসব প্রাণীর প্রজাতি তারা আবিষ্কার করেছেন সেগুলো একেবারে মাথা ঘুরিয়ে দেয়ার মতো। এই প্রাণীগুলো এত বছর পরও অবিকৃত অবস্থায় রয়েছে।
# 945    দুর্নীতির মামলায় সাজাপ্রাপ্ত বিএনপি চেয়ারপার্সন খালেদা জিয়া নির্বাচন করতে পারবেন না - এমন সম্ভাবনা তৈরি হয়েছে সুপ্রিম কোর্টের চেম্বার আদালত শনিবারের এক সিদ্ধান্তে।
# 946    নিকারাগুয়ায় সান্দিনিস্তা বিদ্রোহের তিনমাসের বর্ষপূর্তি উদযাপনের প্রস্তুতি নিচ্ছেন মোনিম্বো শহরের বাদকদল। সেখানে একজন তরুণের মরদেহ সৎকারের জন্য জড়ো হয়েছেন তার আত্মীয় ও বন্ধুরা।
# 947    আমাদের পূর্বপুরুষরা প্রায় দুই লাখ বছর আগে আফ্রিকায় দেখা যেতে শুরু করেছিলেন, এমন একটি গবেষণায় উঠে এসেছে, যেখানে জলবায়ু পরিবর্তনের পর তারা আলাদা হয়ে ছড়িয়ে যায়।
# 948    ব্রিটেনের স্বাস্থ্য সেবা বিভাগের জন্য যে চাঁদা দেয়া হচ্ছে, তা নিয়ে মানুষের মধ্যে ব্যাপক আলোচনা-সমালোচনার ঝড় উঠছে গত কয়েক বছর ধরে। কিন্তু এর সঙ্গে যুক্তরাজ্যে তোলপাড় চলছে।
# 949    বাংলাদেশের রাজধানী ঢাকার রাস্তায় বাস মালিকদের বিরুদ্ধে সিটিং সার্ভিস বন্ধে অভিযান চালানোর অভিযোগ উঠেছে। এর মধ্যে একটি সংগঠন বলছে, একাজে চাঁদা আদায় করা হচ্ছে।
# 950    তুরস্কের গোয়েন্দা সংস্থা বলছে, গত বছর অক্টোবর মাসে সৌদি রাজপরিবারের একজন কঠোর সমালোচক জামাল খাসোগজিকে হত্যার জন্য 'ঘাতক দল' এসে হাজির হয়েছিল।
# 951    কাশ্মীর প্রশ্নে ভারত ও পাকিস্তানের মধ্যে দ্বিপাক্ষিক আলোচনার মাধ্যমে 'মিডিয়েশন বা আরবিট্রেশন' করার অনুরোধ জানিয়েছেন মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প, কিন্তু দিল্লি তা অস্বীকার করেছে।
# 952    বিজ্ঞানীরা বলছেন, বায়ু দূষণকে ডায়াবেটিসের কারণ বলে মনে করা হচ্ছে। কিন্তু নতুন এক গবেষণায় দেখা গেছে, এখনও এই রোগের প্রকোপ দ্রুত বাড়ছে বলে তারা বর্ণনা করছেন।
# 953    মিয়ানমারে সেনা অভ্যুত্থানের পর পদচ্যুত ব্রিটিশ রাষ্ট্রদূত জ জোয়া মিন লন্ডনের দূতাবাস থেকে বের করে দিয়েছেন। এই ঘটনায় যুক্তরাজ্যের পররাষ্ট্রমন্ত্রীর তীব্র সমালোচনা করেছেন তিনি।
# 954    বাংলাদেশে প্রভাব বাড়াতে জোর প্রচেষ্টা চালাচ্ছে চীন। ঢাকায় একটি অনুষ্ঠানের মাধ্যমে মেডিকেল সামগ্রী প্রদান করে তাইওয়ানের তিন মন্ত্রীকে বাংলাদেশের সঙ্গে আলাদা আনুষ্ঠানিক যোগাযোগ দেয়া হয়েছে।
# 955    বাংলাদেশে সরকারি চাকরিতে কোটা পদ্ধতি বাতিলের ঘোষণা নিয়ে শিক্ষার্থীদের আন্দোলনের সময় প্রধানমন্ত্রী এই সিদ্ধান্ত বাস্তবায়ন করা উচিত বলে মন্তব্য করেছেন ঢাকা বিশ্ববিদ্যালয়ের অধ্যাপক শামীমা সুলতানা। তিনি বলেছেন, এখন কোন কৌশল নেই।
# 956    আফ্রিকার দেশ মালি-তে সেনাবাহিনীর অভ্যুত্থানের পর গত কয়েকদিনের মধ্যে সবচেয়ে বেশি মানুষ সেখানে উল্লাস করছেন। কিন্তু এর কোন নতুন ঘটনা ঘটেনি, যার ফলে দেশটিতে সংখ্যালঘু লোকজন প্রাণ হারিয়েছেন।
# 957    বিবিসি হিন্দির দিব্যা আর্য্যার প্রশ্নে সানি লিওন বলছেন, "আপনি কি জানেন যে আমাদের সঙ্গে একজন যৌনকর্মীর ফারাক দেখতে চান? এই প্রশ্নটা আমার মধ্যে ছিল খুব খারাপ।"
# 958    বাংলাদেশের চট্টগ্রামে একজন ছাত্রীকে হাত-পা বেধে ধর্ষণের অভিযোগ ওঠা কোচিং সেন্টারের মালিক নিহত হয়েছে বলে পুলিশের কর্মকর্তারা জানিয়েছেন। র ্যাব দাবি করেছে, অভিযুক্ত ওই শিক্ষক পালিয়ে যান।
# 959    বাংলাদেশের কক্সবাজার জেলার টেকনাফের সাবেক ইয়াবা গডফাদার সাইফুল ইসলাম নিহত হয়েছেন। তিনি মাদক সাম্রাজ্যের একাংশের বেতাজ বাদশা, যার মধ্যে একজন ছিলেন বিএনপির চেয়ারপার্সন আব্দুর রহমান বদী।
# 960    ঈদের ছুটি শুরু হবার আগে থেকেই সরকারি হিসেবেই সব রেকর্ড ভঙ্গ হয়েছিলো ঢাকার সোহরাওয়ার্দী হাসপাতালগুলোতে এডিস মশা আর ডেঙ্গু জ্বরে আক্রান্ত রোগীর সংখ্যা।
# 961    ভারতের পার্লামেন্টে বিতর্কিত নাগরিকত্ব সংশোধনী বিলের বিরুদ্ধে ব্যাপক বিক্ষোভ চলছে, যার ফলে সেখানে ধর্মীয় সংখ্যালঘুদের নির্যাতনের শিকার হতে পারে বলে আশঙ্কা করা হচ্ছে।
# 962    বাংলাদেশের রাজধানী ঢাকায় সিটি কর্পোরেশন নির্বাচনের আগে আইন শৃঙ্খলা রক্ষাকারী বাহিনীর বিশেষ অভিযান অব্যাহত রাখার অভিযোগ করেছে বিরোধীদল বিএনপি। দলটির মহাসচিব আনিসুল হক এবং প্রধান নির্বাচন কমিশনারের সাথে দেখা করে
# 963    যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প এবং উত্তর কোরিয়ার নেতা কিম জং-আন একসাথে বৈঠক করেছেন। কিন্তু এই সমঝোতার কোন মূল্য ছিল না - তা নিয়ে মানুষের মধ্যে ব্যাপক আলোচনা চলছে।
# 964    প্যারিসের একটি রেস্তোঁরায় এক খদ্দেরকে গুলি করে হত্যার ঘটনায় স্থানীয় বাসিন্দারা স্তম্ভিত বলে মন্তব্য করেছেন। তিনি বলছেন, এই ঘটনাটি খুবই দু:খজনক বলে মনে করা হচ্ছে।
# 965    ঢাকার বাসিন্দা রাকিব (ছদ্মনাম) তিন মাস আগে তার ছেলে সন্তানকে যৌন নিপীড়নের শিকার করেছিলো। কিন্তু এই ঘটনা নিয়ে তার পরিবার এখনও আলোচনা করছে না।
# 966    সিরিয়ার পূর্ব ঘুটায় ইসলামী জঙ্গী গোষ্ঠীর বিরুদ্ধে লড়াই অব্যাহত রাখার সিদ্ধান্ত ঘোষণা করেছে জাতিসংঘের নিরাপত্তা পরিষদ। শনিবার নিউ ইয়র্কে আক্রমণ চালিয়েছে বিদ্রোহী অধ্যূষিত হাযা শহর।
# 967    ইউটিউবে নতুন খেলনার মোড়ক খোলার কাজ করেছে ছয় বছরের রায়ান। তার নাম 'রায়ান টয়'স রিভিউ। কিন্তু তার পরিচয় নিয়ে রয়েছে ব্যাপক রহস্য। সেই সঙ্গে তিনি এখন আট নম্বরে।
# 968    বাংলাদেশে ৩০শে ডিসেম্বরের নির্বাচনের জন্য আওয়ামী লীগের দলীয় মনোনয়ন পাওয়ার পর থেকেই সামাজিক যোগাযোগ মাধ্যমে বেশ কিছু ছবি ও ভিডিও ভাইরাল হয়েছে। এর মধ্যে একজন সুদর্শন তরুণ।
# 969    বাংলাদেশে ঢাকার দ্রুত বিচার টাইব্যুনালে ২০১২ সালে বিএনপির নেতা বিশ্বজিৎ দাসকে হত্যার মামলায় আট জনের মৃত্যুদণ্ড এবং ১৩ জরে যাবজ্জীবন সাজা দিয়েছে আদালত।
# 970    বাংলাদেশের রাজধানী ঢাকার একটি সরকারি হাসপাতালে চিকিৎসা নিতে যাচ্ছেন সামিয়া রহমান। গত কয়েকদিন ধরে তাকে মশার কামড় থেকে বাঁচতে দিনের বেলাতে মশারি ব্যবহারের পরামর্শ দেন বিশেষজ্ঞরা।
# 971    বাংলাদেশের রাজধানী ঢাকার বনানীর এফ আর টাওয়ারে আগুনের ঘটনায় নিহতের সংখ্যা ২৬ জনে দাঁড়িয়েছে। এর মধ্যে বেশ কয়েকজনই স্থানীয় বাসিন্দা এবং পুলিশ কর্মকর্তা।
# 972    জাপানের রাজধানী মাইজুরুতে একটি রিং-এর উপর লবণ ছিটানোর ঘটনার পর সেখান থেকে চলে যাওয়া নারী পুরুষের বিষয়ে কোন সিদ্ধান্ত নিতে পারেনি সুমো সমিতির প্রধান।
# 973    হিন্দুত্ববাদী সংগঠন শিবসেনা ও অযোধ্যায় রামমন্দির তৈরির দাবি নিয়ে গত কয়েকদিন ধরে ব্যাপক ভিড় বাড়ছে বলে আশঙ্কা করা হচ্ছে। কিন্তু সেখানে এখন নতুন করে আতঙ্ক দেখা দিয়েছে।
# 974    বাংলাদেশের স্বাধীনতা আন্দোলনের নেতা শেখ মুজিবুর রহমানকে হত্যার ঘটনায় আব্দুল মাজেদের বিরুদ্ধে অভিযোগ এনেছেন ঢাকার পুলিশের একজন কর্মকর্তা। গ্রেপ্তারের পর তাকে আদালতে তোলা হয়েছে।
# 975    মার্কিন প্রেসিডেন্ট নির্বাচনকে কেন্দ্র করে চীনের শীর্ষ নেতা শি জিনপিং ও জো বাইডেনকে ফোন করে অভিনন্দন জানিয়েছেন। কিন্তু এখন পর্যন্ত দুই নেতার মধ্যে কোনো টুইট বা টেলিগ্রামও করা হয়নি।
# 976    আন্তর্জাতিক একটি পত্রিকা টাইম ম্যাগাজিন তাদের বিশেষ সংখ্যায় নিহত সাংবাদিকদের তালিকায় রয়েছে বাংলাদেশের শহিদুল আলম। এর মধ্যে আছেন আরও একশো জন আলোকচিত্রী, যাদের বেশ কয়েক মাস ধরে টানা নির্যাতনের শিকার।
# 977    মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প ইরানের বিরুদ্ধে একটি বি-৫২ বোমারু বিমান পাঠানোর পর এই প্রথমবারের মতো যুক্তরাষ্ট্রের বিমানবাহী জাহাজটি পারস্য উপসাগরে পাঠিয়েছে। এর মধ্যে ইরান এবং ওয়াশিংটন এসব অভিযোগ অস্বীকার কর
# 978    অস্ট্রেলিয়ায় একজন তরুণীর মৃত্যুর ঘটনা ব্যাপক ক্ষোভ ও বিতর্কের জন্ম দিয়েছে। তার পরিবার বলছে, তিনি নিহত হন নারীদের বিরুদ্ধে যৌন নির্যাতন এবং শারীরিক সহিংসতা।
# 979    সলসবেরির ঘটনায় ব্রিটেন এবং রাশিয়ার মধ্যে তীব্র উত্তেজনা তৈরি হবার পর মানব ইতিহাসের সর্বশেষ যুদ্ধ শুরু হতে পারে বলে সতর্ক করে দিয়েছেন একজন সাবেক রুশ গুপ্তচর।
# 980    যুক্তরাজ্য ইউরোপীয় ইউনিয়ন ছাড়ার সিদ্ধান্ত নিয়েছে যে দেশটির গবেষকদের জন্য ভিসা দেয়ার ব্যবস্থা চালু করা হবে। এই পরিকল্পনার বাস্তবায়ন হতে যাচ্ছে আগামী বছরের মধ্যে - যারা ইইউ থেকে বেরিয়ে আসছেন।
# 981    বাংলাদেশের একটি বোয়িং বিমান ঢাকা থেকে দুবাই যাওয়ার কথা ছিল, কিন্তু সেটি ছিনতাই করার চেষ্টা করেছিলেন একজন যাত্রী। এরপর পাইলটকে পিস্তল ধরে প্রধানমন্ত্রী শেখ হাসিনা এবং তার স্ত্রীর সঙ্গে বলা হয়েছিল।
# 982    সড়কে অপ্রত্যাশিত কোন ঘটনা সম্পর্কে আগেভাগে জানতে হয়, কিন্তু সেসব তথ্য যাত্রার বাইরেও পৌঁছাতে লেগে যায়। এরপর সেগুলো দেখা যায় হাইওয়েতে বা নিকটবর্তী জায়গায়।
# 983    বাংলাদেশে আশ্রয় নেয়া রোহিঙ্গাদের মিয়ানমারে ফেরত পাঠিয়ে দিচ্ছে ভারত সরকার, এমন খবর জানিয়েছেন স্থানীয় শরণার্থী , ত্রাণ ও প্রত্যাবাসন কমিশনার মোঃ: আবুল কালাম নূর। তারা বলছেন, দুই মেয়েকে ভয়ে বাংলাদেশের কুতুপালংয়ের একটি ক্যাম্প
# 984    নিকোলাস মাদুরোর সরকার বিরোধী নেতা হুয়ান গুয়াইদো কারাকাসের একটি সেনা ছাউনি থেকে সরে গেছেন। কিন্তু সেনাবাহিনীর সাথে তার সমর্থকদের সংঘর্ষের দৃশ্য দেখা গেছে বলে জানা যাচ্ছে।
# 985    সৌদি আরবের সাবেক প্রধানমন্ত্রী জামাল খাসোগজিকে হত্যার দায়ে জাতিসংঘের একজন কর্মকর্তাকে যাবজ্জীবন কারাদণ্ড দিয়েছে দেশটির রাষ্ট্রদূত হাতিস চেংগিস। তিনি বলেছেন, এ ধরণের হত্যাকাণ্ডের জন্য কখনই কেউ ক্ষমা পতে পারে না।
# 986    ইংল্যান্ডের জাতীয় ক্রিকেট দলের সাবেক অধিনায়ক মইন আলীর সতীর্থ তসলিমা নাসরিন বলেছেন, তিনি সিরিয়ায় গিয়ে আইসিস-এ যোগ দিতে চান কিন্তু তাকে নিয়ে কোনো অনুশোচনা নেই।
# 987    সৌদি আরবে সবচেয়ে বেশি সন্তান মাতৃহীন। কিন্তু সেখানকার অল্প বয়েসী মায়েরা পরিবার ছেড়ে বিদেশে কাজ করতে যাচ্ছেন। কারিমাতুল আবিদিয়া নামের একটি গ্রামে এটাই স্বাভাবিক।
# 988    বাংলাদেশে করোনাভাইরাস সংক্রমণ ঠেকাতে কার্টুনিস্ট ও শিল্পীদের আটক বা হয়রানির ঘটনায় সাংস্কৃতিক অঙ্গনে ভয়াবহ পরিস্থিতি তৈরি হয়েছে বলে অভিযোগ উঠেছে। এর মধ্যে অনেক শিল্পীকে মুক্তি দেয়ার আহ্বান জানিয়েছে সরকার।
# 989    পুরুষদের শুক্রাণু কমে যাবার সংখ্যা দিনে দিনে বাড়ছে বলে একটি গবেষণায় উঠে এসেছে। এই তথ্য দিয়েছে যুক্তরাষ্ট্রের একদল বিজ্ঞানী। তবে তারা বলছেন, এর ফলে ভবিষ্যতে কী ঘটবে তা নিয়ে উদ্বেগ প্রকাশ করেছেন।
# 990    "আমি টিন-এজ সময়টা অনলাইনে প্রকাশ করেছি। আমি জানি অনেক মানুষই এই বিষয়টা ঘৃণা করে। আমার প্রতিটি মুহূর্ত ছিল ১৩ থেকে ১৯ বছরের। সেই সময় থেকেই আমাকে দেখতে ভালবাসি।"
# 991    ফ্রান্সের প্রেসিডেন্ট এমানুয়েল ম্যাক্রঁ বলেছেন, মুসলিমদের ইসলামের নবীর ব্যঙ্গচিত্র প্রদর্শনের অধিকার আছে বলে তিনি মন্তব্য করেছেন। এর জের ধরে তীব্র বিতর্কের মুখে ফরাসী পণ্য বর্জনের ডাক দেয়া হয়েছে।
# 992    মানবদেহে বৃদ্ধাঙ্গুলি বা হাতের অতিরিক্ত পেশী তৈরি হয়তো অনেক বেশি মানুষের শরীরে রয়ে গেছে বলে একটি গবেষণার ফলাফল প্রকাশ করেছে যুক্তরাষ্ট্রের একদল বিজ্ঞানী।
# 993    বাংলাদেশের বিরোধী দল বিএনপির ভারপ্রাপ্ত চেয়ারম্যান তারেক রহমানকে ফিরিয়ে আনার ব্যাপারে ব্রিটেনের সরকার উদ্যোগী হলে তাকে বিচারের জন্য হস্তান্তর করা যেতে পারে বলে জানিয়েছেন আইনমন্ত্রী আনিসুল হক।
# 994    বাংলাদেশে সাগরে ও নদীতে ইলিশ ধরা থেকে বিরত থাকার ঘোষণা দিয়েছে দেশটির মৎস্য গবেষণা ইন্সটিটিউট। কিন্তু এই নিষেধাজ্ঞার লঙ্ঘন করা হলে জরিমানা ও কারাদণ্ডের বিধান রয়েছে।
# 995    বাংলাদেশের অন্যতম প্রধান বিরোধী দল বিএনপির চেয়ারপার্সন খালেদা জিয়ার অবস্থার কোন পরিবর্তন হয়নি বলে জানিয়েছেন ঢাকার এভারকেয়ার হাসপাতালের মেডিকেল বোর্ডের সভাপতি এ জেড এম জাহিদ হোসেন।
# 996    ভারতের কলকাতা শহরে বিজেপি ছাত্র ইউনিটের সামনে আত্মঘাতী হামলায় দু'জন সৈনিক নিহত হওয়ার পর পাকিস্তানের বিরুদ্ধে তীব্র প্রতিবাদ-বিক্ষোভ শুরু হয়েছে। এর মধ্যে একজন ভারতীয় সেনা কর্মকর্তা এবং তিনজন আহত হয়েছেন।
# 997    ইরানের প্রেসিডেন্ট কাসেম সোলেইমানির হত্যাকাণ্ডের বদলা নিতে ইরান বুধবার দুটো মার্কিন ঘাঁটিতে ক্ষেপণাস্ত্র ছুঁড়েছে। কিন্তু এখন এই সংঘাতে কে জিতলো এবং কে হারলো - সেই কাটা-ছেঁড়া হচ্ছে।
# 998    শাহিদা পারভিন ঢাকার বাসিন্দা। সঞ্চয়পত্রের মুনাফার ওপর ১০ শতাংশ কর বহাল রেখে বাজেট পাস হওয়ার পর তিনি বলছেন, সংসারে তার প্রভাব পড়বেই। কিন্তু এই খাতে বিনিয়োগের ক্ষেত্রে তারা কতটা নির্ভরশীল?
# 999    যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প আফগানিস্তানে তালেবানকে সামলাতে ভারতের ভূমিকা নিয়ে নতুন কৌশল প্রকাশ করেছেন। কিন্তু পাকিস্তানের ওপর তীব্র চাপ অব্যাহত রেখেছেন মার্কিন পররাষ্ট্রমন্ত্রী রেক্স টিলারসন।
# 1000    বাংলাদেশের রাজধানী ঢাকার গুলশানে হোলি আর্টিজান রেস্তোঁরায় হামলার পর থেকে জঙ্গিবাদ দমনে সরকারের দক্ষতা বৃদ্ধি এবং আইন শৃঙ্খলা বাহিনীর সক্ষমতা বেড়েছে।
# 1001    বাংলাদেশের চট্টগ্রামে পুলিশ সুপার বাবুল আক্তারের স্ত্রী মাহমুদা আক্তার হত্যার ঘটনায় স্বরাষ্ট্রমন্ত্রী আনিসুল হক বলেছেন, "তিনি একজন সৎ, নির্ভীক ও পরিশ্রমী অফিসার। তিনি দীর্ঘদিন ধরে জঙ্গি দমনে নিরলসভাবে কাজ করে যাচ্ছেন।"
# 1002    বনানীর কামাল আতাতুর্ক এভিনিউর এফআর টাওয়ারে আগুন লাগার পর ঐ ভবনের কাগজপত্র যাচাই করে দেখেছেন রাজউক কর্তৃপক্ষ। কিন্তু ভবনটির নকশা থেকে কোন মিল নেই।
# 1003    বাংলাদেশে করোনাভাইরাসে আক্রান্ত হয়ে গত ২৪ ঘণ্টায় ১০০ জনের মৃত্যু হয়েছে বলে দেশটির স্বাস্থ্য বিভাগ জানিয়েছে। এ নিয়ে দেশটিতে মোট মারা গেলেন ১০ হাজার ৯৫২ জন। এর আগে চারদিন ধরে এই সংখ্যা সবচেয়ে বেশি।
# 1004    যুক্তরাষ্ট্রের সাবেক জাতীয় নিরাপত্তা উপদেষ্টা জন বোল্টন অভিযোগ করেছেন, চীনের প্রেসিডেন্ট শি জিনপিংকে মার্কিন সমালোচকদের সঙ্গে নতুন করে স্নায়ুযুদ্ধ শুরু করতে চেয়েছিলেন ডোনাল্ড ট্রাম্প।
# 1005    হোয়াটসঅ্যাপ কর্তৃপক্ষ ভারতের জন্য কিছু কড়াকড়ি আরোপ করেছে। ভারতে ছেলেধরা সন্দেহে গণপিটুনি দেওয়ার পর গত দেড় মাসে কুড়ি জনেরও বেশী মানুষকে পিটিয়ে মেরে ফেলা হয়।
# 1006    চীনের পশ্চিম শিনজিয়াং প্রদেশের একটি বিশাল বন্দীশিবিরে সম্প্রতি ব্যাপক সম্প্রসারণ করা হয়েছে। এর ফলে এখন পর্যন্ত এই শিবিরের ধারণক্ষমতা এক লক্ষেরও বেশি হতে পারে।
# 1007    বিশ্ব স্বাস্থ্য সংস্থা বলছে চীনে করোনাভাইরাসে আক্রান্ত মানুষের সংখ্যা গত কয়েক দিনের মধ্যে সবচেয়ে বেশি এবং এই ভাইরাস মহামারির মত ছড়িয়ে পড়তে পারে বলে আশঙ্কা রয়েছে।
# 1008    বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা জামালপুরের প্রত্যন্ত চরে আটকে রয়েছে ভারতীয় একটি বুনো হাতি। সেটিকে উদ্ধারের জন্য দুই দেশের বন কর্মকর্তারা সেখান থেকে সরে যাওয়ার চেষ্টা করছেন। এরপর সেটির অবস্থা বোঝা যাচ্ছে না।
# 1009    সৌদি আরবে নারীদের পাসপোর্ট বানানো বা দেশের বাইরে ভ্রমণের ক্ষেত্রে পুরুষের সমকক্ষতা দেয়া বাধ্যতামূলক ঘোষণা করেছে দেশটির রাজকীয় ফরমান। এর ফলে এই নারীদেরকে সব ধরণের বৈষম্য তৈরি করতে হবে।
# 1010    ভারতে মেয়েদের নিয়ে যৌন হয়রানিমূলক মন্তব্য করার অভিযোগে একটি ইনস্টাগ্রাম গ্রুপকে গ্রেফতার করা হয়েছে বলে জানা যাচ্ছে। এটি ভারতের সবচেয়ে বড় স্কুলপড়ুয়া কিশোরদের নাম।
# 1011    চীনের শিনজিয়াংএ বন্দীশিবিরে উইগর মুসলিমদের ওপর গণ-নজরদারির একটি অ্যাপ তৈরি করেছে চীন। মানবাধিকার সংগঠন হিউম্যান রাইটস ওয়াচ এবং জাতিসংঘ বলছে, এই অ্যাপের ব্যবহার করা হচ্ছে 'উইগ

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab')
# Out:
# ['mt5_test.csv']

# %%
genDf.to_csv('mT5_test_local.csv')  # Saves locally in the Colab environment

# %%
from google.colab import files
files.download('mT5_test_local.csv')

# %%
import os

save_path = '/content/gdrive/My Drive/Colab'
os.makedirs(save_path, exist_ok=True)  # Create the directory if it doesn't exist

# Now save the file
genDf.to_csv(f'{save_path}/mT5_test.csv')

# %%
import os
os.listdir('/content/gdrive/My Drive/Colab')
# Out:
# ['mT5_1.csv', 'test.csv', 'mt5_1.csv', 'mT5.csv', 'test2.csv']

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab/mT5_test.csv')

# Display the first few rows to verify the file is loaded properly
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  আটক স্বজনদের আইডি কার্ড হাতে উইগুর নারীদের বিক...
# 1           1  ভারতের অন্য অঞ্চলেও কোক, পেপসি নিষিদ্ধ করার দা...
# 2           2  সোহরাওয়ার্দী হাসপাতালের চিত্র সাধারণত সেপ্টেম...
# 3           3  ডোনাল্ড ট্রাম্প অভিযোগ করেছেন টু্‌ইটার আমেরিকা...
# 4           4  বন্যার প্রকোপ ছড়িয়ে পড়ছে সারা দেশে। বাংলাদে...
#
#                                         givenSummary  \
# 0  জাতিসংঘের মানবাধিকার বিষয়ক কমিটি জেনেভাতে চীন...
# 1  ভারতের দক্ষিণাঞ্চলীয় রাজ্য তামিলনাডুর ব্যবসায...
# 2  স্বাস্থ্য অধিদপ্তরের হিসাব মতে, গত ২৪ ঘণ্টায় ...
# 3  এই প্রথম সামাজিক মাধ্যমের বিশাল প্রতিষ্ঠান টুই...
# 4  বাংলাদেশের বন্যা পূর্বাভাস এবং সতর্কীকরণ কেন্দ...
#
#                                       mT5_Test_XLSum
# 0  জাতিসংঘের একটি মানবাধিকার সংস্থা অভিযোগ করেছে,...
# 1  ভারতের তামিলনাডু রাজ্যে কোকা-কোলা এবং পেপসি নি...
# 2  বাংলাদেশের রাজধানী ঢাকার বেশ কয়েকটি হাসপাতাল ...
# 3  যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প অভি...
# 4  বাংলাদেশের উত্তরের চারটি জেলা আগামী ২৪ ঘণ্টার ...

# %%
df
# Out:
#       Unnamed: 0                                               text  \
# 0              0  আটক স্বজনদের আইডি কার্ড হাতে উইগুর নারীদের বিক...
# 1              1  ভারতের অন্য অঞ্চলেও কোক, পেপসি নিষিদ্ধ করার দা...
# 2              2  সোহরাওয়ার্দী হাসপাতালের চিত্র সাধারণত সেপ্টেম...
# 3              3  ডোনাল্ড ট্রাম্প অভিযোগ করেছেন টু্‌ইটার আমেরিকা...
# 4              4  বন্যার প্রকোপ ছড়িয়ে পড়ছে সারা দেশে। বাংলাদে...
# ...          ...                                                ...
# 1007        1007  বিশ্ব স্বাস্থ্য সংস্থা বলছে মহামারী আকারে পুরো...
# 1008        1008  জামালপুরের প্রত্যন্ত চরে আটকে রয়েছে ভারতীয় এ...
# 1009        1009  ভ্রমণের অধিকারের হিসেবে সৌদি আরবের নারীদেরকে প...
# 1010        1010  মেয়েদের নিয়ে যৌন হয়রানিমূলক মন্তব্য করায় গ...
# 1011        1011  মোবাইল অ্যাপ দিয়ে উইগরদের ওপর নজরদারি করছে চী...
#
#                                            givenSummary  \
# 0     জাতিসংঘের মানবাধিকার বিষয়ক কমিটি জেনেভাতে চীন...
# 1     ভারতের দক্ষিণাঞ্চলীয় রাজ্য তামিলনাডুর ব্যবসায...
# 2     স্বাস্থ্য অধিদপ্তরের হিসাব মতে, গত ২৪ ঘণ্টায় ...
# 3     এই প্রথম সামাজিক মাধ্যমের বিশাল প্রতিষ্ঠান টুই...
# 4     বাংলাদেশের বন্যা পূর্বাভাস এবং সতর্কীকরণ কেন্দ...
# ...                                                 ...
# 1007  করোনাভাইরাসে আক্রান্ত হয়ে মৃত্যুর সংখ্যা ১৭০ ...
# 1008  বাংলাদেশের জামালপুরের একটি চরে আটকে থাকা ভারতী...
# 1009  এখন থেকে সৌদি আরবের নারীরা কোনো পুরুষ অভিভাবকে...
# 1010  ইনস্টাগ্রাম গ্রুপ চ্যাটে অপ্রাপ্তবয়স্ক মেয়েদ...
# 1011  চীনে শিনজিয়াং প্রদেশের উইগর মুসলিম জনগোষ্ঠীর ...
#
#                                          mT5_Test_XLSum
# 0     জাতিসংঘের একটি মানবাধিকার সংস্থা অভিযোগ করেছে,...
# 1     ভারতের তামিলনাডু রাজ্যে কোকা-কোলা এবং পেপসি নি...
# 2     বাংলাদেশের রাজধানী ঢাকার বেশ কয়েকটি হাসপাতাল ...
# 3     যুক্তরাষ্ট্রের প্রেসিডেন্ট ডোনাল্ড ট্রাম্প অভি...
# 4     বাংলাদেশের উত্তরের চারটি জেলা আগামী ২৪ ঘণ্টার ...
# ...                                                 ...
# 1007  বিশ্ব স্বাস্থ্য সংস্থা বলছে চীনে করোনাভাইরাসে ...
# 1008  বাংলাদেশের দক্ষিণাঞ্চলীয় জেলা জামালপুরের প্রত...
# 1009  সৌদি আরবে নারীদের পাসপোর্ট বানানো বা দেশের বাই...
# 1010  ভারতে মেয়েদের নিয়ে যৌন হয়রানিমূলক মন্তব্য ক...
# 1011  চীনের শিনজিয়াংএ বন্দীশিবিরে উইগর মুসলিমদের ওপ...
#
# [1012 rows x 4 columns]

# %%
# View the original text, given summary, and generated summary for the first row
sample_index = 0  # You can change this to inspect different rows

# Access text, given summary (if available), and generated summary
original_text = df['text'][sample_index]
given_summary = df['givenSummary'][sample_index]  # If present in the CSV
generated_summary = df['mT5_Test_XLSum'][sample_index]

# Print the text and corresponding summaries
print(f"Original Text:\n{original_text}\n")
print(f"Given Summary (if available):\n{given_summary}\n")
print(f"Generated Summary:\n{generated_summary}\n")
# Out:
# Original Text:
# আটক স্বজনদের আইডি কার্ড হাতে উইগুর নারীদের বিক্ষোভ (ফাইল ফটো) অভিযোগ করেন জাতিসংঘের জাতিগত বৈষম্য বিষয়ক কমিটির সদস্য গে ম্যাকডুগাল। তিনি বলেন, এমন খবর তিনি পেয়েছেন যে চীনা কর্তৃপক্ষ স্বায়ত্তশাসিত উইগুর প্রদেশকে কার্যত "বিশাল একটি বন্দীশিবিরে" রূপান্তরিত করেছে। চীন সাথে সাথে এর কোনো জবাব দেয়নি। ৫০-সদস্যের চীনা প্রতিনিধিদলের পক্ষ থেকে বলা হয়, সোমবার এই অভিযোগের জবাব দেওয়া হবে। তবে এর আগে বিভিন্ন সময় চীন বলেছে, এ ধরণের বন্দী শিবিরের কোনো অস্তিত্ব নেই। বাজারে উইগুর পুরুষদের জটলা (ফাইল ফটো, ২০১৩)। চীনা কোনো বন্দীশিবিরের অস্তিত্ব অস্বীকার করে। উইগুর মুসলিম কারা? চীনের জিনজিয়াং প্রদেশের জনসংখ্যার ৪৫ শতাংশ উইগুর মুসলিম। এই প্রদেশটি তিব্বতের মত স্বশাসিত একটি অঞ্চল। বিদেশী মিডিয়ার ওপর এখানে যাবার ব্যাপারে কঠোর বিধিনিষেধ রয়েছে। কিন্তু গত বেশ ক'মাস ধরে বিভিন্ন সূত্রে খবরাখবর বেরুচ্ছে যে শিনজিয়াং-এ উইগুর এবং অন্যান্য মুসলিমরা ব্যাপকহারে আটকের শিকার হচ্ছে। ঠিক কি জন্য চীনকে অভিযুক্ত করা হচ্ছে? হিউম্যান রাইটস ওয়াচ এবং অ্যামনেস্টি ইন্টারন্যাশনাল সহ অন্যান্য আন্তর্জাতিক মানবাধিকার সংস্থা জাতিসংঘের মানবাধিকার বিষয়ক কমিটির কাছে দেওয়া তাদের রিপোর্টে বলেছে, উইগুর মুসলিমদের গণহারে ধরে বিভিন্ন বন্দীশিবিরে নেয়া হচ্ছে। এরপর সেসব শিবিরে তাদেরকে জোর করে চীনা প্রেসিডেন্ট শি জিনপিংয়ের প্রতি আনুগত্য প্রকাশে বাধ্য করা হচ্ছে। নির্বাসিত উইগুর মুসলিমদের সংগঠন ওয়ার্ল্ড উইগুর কংগ্রেস তাদের এক রিপোর্টে বলেছে, কোনো অভিযোগ ছাড়াই উইগুরদের ধরে অনির্দিষ্টকালের জন্য আটকে রাখা হচ্ছে, এবং তাদেরকে জোর করে চীনা কম্যুনিস্ট পার্টির পক্ষে স্লোগান দিতে বলা হচ্ছে। ওয়ার্ল্ড উইগুর কংগ্রেস দাবি করছে, বন্দীদের ঠিকমত খাবার দেওয়া হয়না এবং নানাভাবে নির্যাতন করা হয়। বলা হচ্ছে, অধিকাংশ বন্দীকে দীর্ঘদিন আটকে রাখলেও তাদেরকে অভিযুক্ত করা হয়না এবং কোনো আইনি সহায়তা নিতেও দেওয়া হয়না। ধর্মীয় কট্টরবাদ মোকাবেলার যুক্তিতে চীনা কর্তৃপক্ষ এভাবে গণ-আটকের পথ নিয়েছে। আরও পড়ুন: চীনে মসজিদ ভাঙ্গার বিরুদ্ধে দাঁড়িয়েছে মুসলিমরা সামরিক শক্তিতে মার্কিন ভাবনারও সীমা ছাড়িয়েছে চীন তুরস্কের ইস্তাম্বুলে চীনা কনস্যুলেটের বাইরে নির্বাসিত উইগুরদের বিক্ষোভ (ফাইল ফটো) চীন কি বলে? চীনের সরকার সবসময় বলে এ ধরনের কোনো বন্দীশিবিরের কোনো অস্তিত্বই সেখানে নেই। এপ্রিলে মার্কিন একজন সিনিয়র কূটনীতিক ল্যরা স্টোন বলেছিলেন, "পুনঃ-শিক্ষা কেন্দ্রগুলোতে" লাখ লাখ মানুষকে আটকে রাখা হয়েছে। প্রতিক্রিয়ায় চীনের পররাষ্ট্র মন্ত্রণালয়ের মুখপাত্র তখন বলেছিলেন, "সবাই জানে এবং দেখে যে শিনজিয়াংয়ে সব জাতিগোষ্ঠী শান্তি এবং সমৃদ্ধির মাঝে পাশাপাশি বসবাস করছে।" পর্যবেক্ষকরা বলছেন, চীনা মুসলিম সমাজে মধ্যপ্রাচ্যের ঘরানার ইসলামী ভাবধারা ঢুকে পড়ছে বলে বেইজিংয়ের মধ্যে বেশ কিছুদিন ধরে উদ্বেগ শুরু হয়েছে। গতকাল (শুক্রবার) উত্তর-পশ্চিমের নিংশিয়া প্রদেশের উইজু শহরে কর্তৃপক্ষ একটি "অননুমোদিত" মসজিদ ভেঙ্গে ফেলার উদ্যোগ নিলে এলাকার শত শত মুসলিম তাতে বাধা দেয়। চীনা মুসলিমরা শত শত বছর ধরে মসজিদ বা অন্যান্য ধর্মীয় স্থাপনা নির্মাণের সময় চীনের ঐতিহ্যবাহী নকশা এবং স্থাপত্য অনুসরণ করে আসছে। কিন্তু উইজুতে যে মসজিদ নিয়ে গণ্ডগোল বেঁধেছে সেটিতে মধ্যপ্রাচ্যের মত মিনার এবং গম্বুজ তৈরি করা হয়। কর্তৃপক্ষ বলছে এই নকশার কোনো অনুমোদন দেওয়া হয়নি।
#
# Given Summary (if available):
# জাতিসংঘের মানবাধিকার বিষয়ক কমিটি জেনেভাতে চীনের ওপর দুদিনের যে বিশেষ সভা করছে, সেখানে অভিযোগ করা হয়, কট্টরপন্থী সন্দেহে ১০ লাখ চীনা উইগুর মুসলিমকে বিভিন্ন রাজনৈতিক শিবিরে আটকে রাখা হয়েছে।
#
# Generated Summary:
# জাতিসংঘের একটি মানবাধিকার সংস্থা অভিযোগ করেছে, চীনের জিনজিয়াং প্রদেশে উইগুর মুসলিমদের গণহারে ধরে বিভিন্ন বন্দীশিবিরে রূপান্তরিত করার ঘটনায় চীনকে অভিযুক্ত করা হয়েছে।

# %% [markdown]
# # **ROGUE SCORE**

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.0.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.6.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (16.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
# !pip install rouge_score
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.5)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=7c6ca5f67a7ddf2b1f1cf2e97074682715975f973cb054f6daf2b7c4caa506c9
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
# !pip install rouge

import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from rouge import Rouge
from csv import DictReader
# Out:
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# 1000
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def rougeScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)
    # return SummaryEv
    urlCSV = '/content/' + columnName + 'CSV.csv'
    SummaryEv.to_csv(urlCSV, index=False)

    with open(urlCSV, 'r') as f:
        dict_reader = DictReader(f)
        SummaryEv_dict = list(dict_reader)

    EvJson = json.dumps(SummaryEv_dict, indent = 4)
    JSON = columnName + 'EvJson.json'
    save_file_at_dir('/content', JSON, EvJson)

    urlJSON = '/content/' + columnName + 'EvJson.json'

    with open(urlJSON) as f:
        SummaryEvData = json.load(f)
    lenS = len(SummaryEvData)
    rscore1r = 0
    rscore1p = 0
    rscore1f = 0
    rscore2r = 0
    rscore2p = 0
    rscore2f = 0
    rscorelr = 0
    rscorelp = 0
    rscorelf = 0
    rouge = Rouge()
    for i in range(lenS):
        score = rouge.get_scores(SummaryEvData[i][columnName], SummaryEvData[i]['givenSummary'])
        rscore1r = rscore1r + score[0]['rouge-1']['r']
        rscore1p = rscore1p + score[0]['rouge-1']['p']
        rscore1f = rscore1f + score[0]['rouge-1']['f']
        rscore2r = rscore2r + score[0]['rouge-2']['r']
        rscore2p = rscore2p + score[0]['rouge-2']['p']
        rscore2f = rscore2f + score[0]['rouge-2']['f']
        rscorelr = rscorelr + score[0]['rouge-l']['r']
        rscorelp = rscorelp + score[0]['rouge-l']['p']
        rscorelf = rscorelf + score[0]['rouge-l']['f']

        # rscore = [[rscore1r/lenS, rscore1p/lenS, rscore1f/lenS],
        #           [rscore2r/lenS, rscore2p/lenS, rscore2f/lenS],
        #           [rscorelr/lenS, rscorelp/lenS, rscorelf/lenS]]

    rscore = {'rouge-1': {'r': rscore1r/lenS,
                        'p': rscore1p/lenS,
                        'f': rscore1f/lenS},
                'rouge-2': {'r': rscore2r/lenS,
                        'p': rscore2p/lenS,
                        'f': rscore2f/lenS},
                'rouge-l': {'r': rscorelr/lenS,
                        'p': rscorelp/lenS,
                        'f': rscorelf/lenS}}
    return rscore

# %%
mx = rougeScore('mT5_Test_XLSum')
mx
# Out:
# {'rouge-1': {'r': 0.2430215947021091,
#   'p': 0.1853853900376309,
#   'f': 0.20501458906352663},
#  'rouge-2': {'r': 0.08511142904028536,
#   'p': 0.0631889296638337,
#   'f': 0.0703855517212657},
#  'rouge-l': {'r': 0.20070258424028023,
#   'p': 0.15144650405818583,
#   'f': 0.16820770314197908}}

# %%
def getScore(m, n, x):
    strs = 'rouge-'+str(n)
    return m[strs][x]

# %%
data = {'columns':['rouge-1 r', 'rouge-1 p', 'rouge-1 f', 'rouge-2 r', 'rouge-2 p', 'rouge-2 f', 'rouge-l r', 'rouge-l p', 'rouge-l f'],
        'mT5_Test_XLSum':[getScore(mx, 1, 'r'), getScore(mx, 1, 'p'), getScore(mx, 1, 'f'), getScore(mx, 2, 'r'), getScore(mx, 2, 'p'), getScore(mx, 2, 'f'), getScore(mx, 'l', 'r'), getScore(mx, 'l', 'p'), getScore(mx, 'l', 'f')],
       }

rougeDf = pd.DataFrame(data)
rougeDf_ = rougeDf
rougeDf = rougeDf.reset_index(drop=True).T
rougeDf = rougeDf.rename(columns=rougeDf.iloc[0]).drop(rougeDf.index[0])
rougeDf.reset_index(inplace=True)
rougeDf = rougeDf.rename(columns = {'index':'Summary'})
rougeDf
# Out:
#           Summary rouge-1 r rouge-1 p rouge-1 f rouge-2 r rouge-2 p rouge-2 f  \
# 0  mT5_Test_XLSum  0.243022  0.185385  0.205015  0.085111  0.063189  0.070386
#
#   rouge-l r rouge-l p rouge-l f
# 0  0.200703  0.151447  0.168208

# %%
import matplotlib.pyplot as plt

# plotting graph
rougeDf.plot(x="Summary",
               y=['rouge-1 r',
                'rouge-1 p',
                'rouge-1 f',
                'rouge-2 r',
                'rouge-2 p',
                'rouge-2 f',
                'rouge-l r',
                'rouge-l p',
                'rouge-l f'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Rouge Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **BLEU SCORE**

# %%
import os
import json
from csv import DictReader

def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

genDf.to_csv('/content/bleuEvCSV.csv', index=False)

with open("/content/bleuEvCSV.csv", 'r') as f:
    dict_reader = DictReader(f)
    bleu_dict = list(dict_reader)
print(len(bleu_dict))

bleuEvJson = json.dumps(bleu_dict, indent = 4)
save_file_at_dir('/content', 'bleuEvJson.json', bleuEvJson)

with open('/content/bleuEvJson.json') as f:
  bleuData = json.load(f)
# Out:
# 1012

# %%
import nltk

def bleuCorpass(columnName):
    ble1score = 0
    ble2score = 0
    ble3score = 0
    ble4score = 0
    for i in range(len(bleuData)):
        hypothesis = bleuData[i][columnName].split()
        reference = bleuData[i]['givenSummary'].split()
        references = [reference]
        list_of_references = [references]
        list_of_hypotheses = [hypothesis]
        ble1score = ble1score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(1, 0, 0, 0))
        ble2score = ble2score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.5, 0.5, 0, 0))
        ble3score = ble3score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.33, 0.33, 0.33, 0))
        ble4score = ble4score + nltk.translate.bleu_score.corpus_bleu(list_of_references, list_of_hypotheses, weights=(0.25, 0.25, 0.25, 0.25))

    print("Bleu 1: ", ble1score/len(bleuData),'\n')
    print("Bleu 2: ", ble2score/len(bleuData),'\n')
    print("Bleu 3: ", ble3score/len(bleuData),'\n')
    print("Bleu 4: ", ble4score/len(bleuData),'\n')

    return ble1score/len(bleuData), ble2score/len(bleuData), ble3score/len(bleuData), ble4score/len(bleuData)

# %%
print('mT5_Test_XLSum Bleu:', bleuCorpass('mT5_Test_XLSum'))
# Out:
# Bleu 1:  0.175335879977202
#
# Bleu 2:  0.08897480720949393
#
# Bleu 3:  0.04744566824728539
#
# Bleu 4:  0.024277377369747128
#
# mT5_Test_XLSum Bleu: (0.175335879977202, 0.08897480720949393, 0.04744566824728539, 0.024277377369747128)

# %% [markdown]
# # **BERTSCORE**

# %%
# !pip install bert_score
# Out:
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.44.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.24.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
from evaluate import load
bertscore = load("bertscore")
# Out:
# Downloading builder script:   0%|          | 0.00/7.95k [00:00<?, ?B/s]

# %%
import sys
print(sys.getrecursionlimit())
sys.setrecursionlimit(8200)
print(sys.getrecursionlimit())

import os
import json
from csv import DictReader
# Out:
# 8200
# 8200

# %%
def save_file_at_dir(dir_path, filename, file_content, mode='w'):
    os.makedirs(dir_path, exist_ok=True)
    with open(os.path.join(dir_path, filename), mode) as f:
        f.write(file_content)

# %%
def bertScore(columnName):
    SummaryEv = genDf.filter(['text', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    bert_precision = 0
    bert_recall = 0
    bert_f1 = 0

    for i in range(lenS):
        results = bertscore.compute(predictions=[SummaryEv[columnName][i]], references=[SummaryEv['text'][i]], lang="bn")

        bert_precision = bert_precision + results['precision'][0]
        bert_recall = bert_recall + results['recall'][0]
        bert_f1 = bert_f1 + results['f1'][0]

    bert_score = {'precision': bert_precision/lenS,
                    'recall': bert_recall/lenS,
                    'f1': bert_f1/lenS}
    return bert_score

# %%
mx = bertScore('mT5_Test_XLSum')
mx
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# {'precision': 0.8015594120199973,
#  'recall': 0.6516811232793002,
#  'f1': 0.7187212038888291}

# %%
def getScore(m, x):
    strs = x
    return m[strs]

# %%
import pandas as pd

data = {'columns':['bert_precision', 'bert_recall', 'bert_f1'],
        'mT5_Test_XLSum':[getScore(mx, 'precision'), getScore(mx, 'recall'), getScore(mx, 'f1')],
       }

bertScoreDf = pd.DataFrame(data)
bertScoreDf_ = bertScoreDf
bertScoreDf = bertScoreDf.reset_index(drop=True).T
bertScoreDf = bertScoreDf.rename(columns=bertScoreDf.iloc[0]).drop(bertScoreDf.index[0])
bertScoreDf.reset_index(inplace=True)
bertScoreDf = bertScoreDf.rename(columns = {'index':'Summary'})
bertScoreDf
# Out:
#           Summary bert_precision bert_recall   bert_f1
# 0  mT5_Test_XLSum       0.801559    0.651681  0.718721

# %%
import matplotlib.pyplot as plt

# plotting graph
bertScoreDf.plot(x="Summary",
               y=['bert_precision',
                'bert_recall',
                'bert_f1'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Bert Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# # **WIL WER METEOR WITH GIVEN SUMMARY**

# %%
from collections import Counter

class MeteorScore:
    def __init__(self, alpha=0.5, beta=0.5, gamma=0.5):
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma

    def preprocess_sentence(self, sentence):
        words = sentence.split()
        return words

    def ngram_count(self, sentence, n):
        words = self.preprocess_sentence(sentence)
        ngrams = [tuple(words[i:i+n]) for i in range(len(words)-n+1)]
        return Counter(ngrams)

    def compute_precision(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        precision = overlap / sum(hyp_counts.values()) if sum(hyp_counts.values()) > 0 else 0
        return precision

    def compute_recall(self, hypothesis, reference, n):
        hyp_counts = self.ngram_count(hypothesis, n)
        ref_counts = self.ngram_count(reference, n)
        overlap = sum((hyp_counts & ref_counts).values())
        recall = overlap / sum(ref_counts.values()) if sum(ref_counts.values()) > 0 else 0
        return recall

    def meteor_score(self, hypothesis, reference):
        precision = self.alpha * self.compute_precision(hypothesis, reference, 1) + (1-self.alpha) * self.compute_precision(hypothesis, reference, 2)
        recall = self.beta * self.compute_recall(hypothesis, reference, 1) + (1-self.beta) * self.compute_recall(hypothesis, reference, 2)
        fmean = (1-self.gamma) * precision + self.gamma * recall if (precision != 0 and recall != 0) else 0
        return fmean

# %%
# !pip install jiwer
import jiwer
# Out:
# Collecting jiwer
#   Downloading jiwer-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 48.5 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.4 rapidfuzz-3.10.1

# %%
meteor = MeteorScore(alpha=0.5, beta=0.5, gamma=0.5)

def wilWerMeteorScore(columnName):
    SummaryEv = genDf.filter(['givenSummary', columnName], axis=1)

    lenS = SummaryEv.shape[0]
    wer_score = 0
    meteor_score = 0
    wil_score = 0

    for i in range(lenS):
        wer_result = jiwer.wer(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])
        meteor_result = meteor.meteor_score(SummaryEv[columnName][i], SummaryEv['givenSummary'][i])
        wil_result = jiwer.wil(SummaryEv['givenSummary'][i], SummaryEv[columnName][i])

        wer_score = wer_score + wer_result
        meteor_score = meteor_score + meteor_result
        wil_score = wil_score + wil_result

    wilWerMeteor_score = {'METEOR': meteor_score/lenS,
                    'WER': wer_score/lenS,
                    'WIL': wil_score/lenS}

    return wilWerMeteor_score
    # return spice_score/lenS

# %%
mx = wilWerMeteorScore('mT5_Test_XLSum')
mx
# Out:
# {'METEOR': 0.14285121125079894,
#  'WER': 1.285731610683799,
#  'WIL': 0.9745071088763727}

# %%
import pandas as pd

data = {'columns':['WIL', 'METEOR', 'WER'],
        'mT5_Test_XLSum':[getScore(mx, 'WIL'), getScore(mx, 'METEOR'), getScore(mx, 'WER')],
       }

threeScoreDf = pd.DataFrame(data)
threeScoreDf_ = threeScoreDf
threeScoreDf = threeScoreDf.reset_index(drop=True).T
threeScoreDf = threeScoreDf.rename(columns=threeScoreDf.iloc[0]).drop(threeScoreDf.index[0])
threeScoreDf.reset_index(inplace=True)
threeScoreDf = threeScoreDf.rename(columns = {'index':'Summary'})
threeScoreDf
# Out:
#           Summary       WIL    METEOR       WER
# 0  mT5_Test_XLSum  0.974507  0.142851  1.285732

# %%
import matplotlib.pyplot as plt

# plotting graph
threeScoreDf.plot(x="Summary",
               y=['WIL', 'METEOR', 'WER'],
               kind="bar", figsize=(25, 12))

plt.suptitle("Three Score of the summaries in Barplot\n\n\n\n\n\n")
plt.ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x = np.arange(len(metrics))

plt.bar(x, values, width=bar_width, color='skyblue')
plt.xticks(x, metrics, rotation=45, ha='right')
plt.ylabel('Score')
plt.title('Evaluation Metrics for Text Summarization')

# Optionally add a grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Define the metrics and their values
metrics = [
    'ROUGE-1 (F1)', 'ROUGE-2 (F1)', 'ROUGE-L (F1)',
    'BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4',
    'BERTScore (Precision)', 'BERTScore (Recall)', 'BERTScore (F1)',
    'METEOR', 'WER'
]

# Extracted values
values = [
    0.1666,   # ROUGE-1 F1
    0.0598,   # ROUGE-2 F1
    0.1535,   # ROUGE-L F1
    0.1067,   # BLEU-1
    0.0529,   # BLEU-2
    0.0256,   # BLEU-3
    0.0104,   # BLEU-4
    0.8277,   # BERTScore Precision
    0.6640,   # BERTScore Recall
    0.7366,   # BERTScore F1
    0.1642,   # METEOR
    3.1958    # WER
]

# Create a DataFrame
df = pd.DataFrame({'Metric': metrics, 'Score': values})

# Display the table
print(df)

# If you want to export the table to a CSV file
# df.to_csv('/content/summary_evaluation_metrics.csv', index=False)
# Out:
#                    Metric   Score
# 0            ROUGE-1 (F1)  0.1666
# 1            ROUGE-2 (F1)  0.0598
# 2            ROUGE-L (F1)  0.1535
# 3                  BLEU-1  0.1067
# 4                  BLEU-2  0.0529
# 5                  BLEU-3  0.0256
# 6                  BLEU-4  0.0104
# 7   BERTScore (Precision)  0.8277
# 8      BERTScore (Recall)  0.6640
# 9          BERTScore (F1)  0.7366
# 10                 METEOR  0.1642
# 11                    WER  3.1958

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import matplotlib.pyplot as plt

human_lengths = genDf['givenSummary'].apply(lambda x: len(x.split()))
generated_lengths = genDf['mT5_Test_XLSum'].apply(lambda x: len(x.split()))

plt.scatter(human_lengths, generated_lengths)
plt.xlabel('Human Summary Length')
plt.ylabel('Generated Summary Length')
plt.title('Human vs. Generated Summary Length')
plt.show()

# %%
gen_length = [len(summary.split()) for summary in genDf["mT5_Test_XLSum"]]
ref_length = [len(summary.split()) for summary in genDf["givenSummary"]]

plt.figure(figsize=(10, 6))
plt.scatter(ref_length, gen_length, alpha=0.5)
plt.xlabel("Reference Summary Length (words)")
plt.ylabel("Generated Summary Length (words)")
plt.title("Generated vs. Reference Summary Length")
plt.plot([0, max(ref_length)], [0, max(ref_length)], color='red', linestyle='--')  # Diagonal line
plt.show()

# %% [markdown]
# # **TEST (NOT INCLUDED)**

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from normalizer import normalize  # Assuming you have this installed
import re

# Device setup
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# Load the model and tokenizer
model_name = "csebuetnlp/mT5_multilingual_XLSum"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Move the model to the correct device (GPU or CPU)
model.to(device)

# Define the whitespace handler
WHITESPACE_HANDLER = lambda k: re.sub('\s+', ' ', re.sub('\n+', ' ', k.strip()))

# Function to generate a summary
def generate_summary(input_text):
    # Normalize the text (if needed)
    input_text = normalize(input_text)

    # Tokenize the input text
    input_ids = tokenizer(
        [WHITESPACE_HANDLER(input_text)],
        return_tensors="pt",
        padding="max_length",
        max_length=512,
        truncation=True
    )["input_ids"]

    # Generate the summary
    output_ids = model.generate(
        input_ids=input_ids.to(device),
        max_length=400,
        min_length=64,
        no_repeat_ngram_size=2,
        num_beams=4
    )[0]

    # Decode the generated summary
    summary = tokenizer.decode(
        output_ids,
        skip_special_tokens=True,
        clean_up_tokenization_spaces=False
    )

    return summary
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# Example of custom input text
custom_text = """
  'ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়ার গাড়ি, বাড়ি, প্লট, ফ্ল্যাট-কী নেই। রীতিমতো গড়েছেন সম্পদের পাহাড়। শুধু নিজের
  নামেই নয়; স্ত্রী, ছেলে-মেয়ে এবং শ্যালক-শ্যালিকার নামেও গড়েছেন বিপুল সম্পত্তি।\nঅভিযোগ রয়েছে, ডিএমপিতে ‘ঘুষ’ এবং বদলি বাণিজ্যে গড়ে তুলেছেন এসব
  সম্পদ। তার বিপুল সম্পদের বিষয়ে অনুসন্ধান চালাচ্ছে দুর্নীতি দমন কমিশন (দুকক)। যুগান্তরের অনুসন্ধানি প্রতিবেদনে এসব তথ্য ওঠে এসেছে।\nপ্রতিবেদনে জানা যায়,
  রাজধানীর অভিজাত এলাকা সিদ্ধেশ্বরীর ভিকারুননিসা স্কুলের পাশেই রূপায়ণ স্বপ্ন নিলয়। ৫৫/১ হোল্ডিংয়ে আলিশান এ ভবনটি ১১ তলা। এখানে প্রায় সাড়ে ৩ হাজার বর্গফিটের
  একটি ফ্ল্যাট রয়েছে আছাদুজ্জামানের মেয়ে আয়েশা সিদ্দিকার নামে।\nশুক্রবার (২৩ আগস্ট) দুপুরে সেখানে গেলে নিরাপত্তা ইনচার্জ আবুল কালাম আজাদ যুগান্তরকে
   বলেন, তিনি মাস দেড়েক আগে এখানে চাকরি নিয়েছেন। এই ভবনে ১৩০টি ফ্ল্যাট। তাই সব ফ্ল্যাট মালিককে ভালোভাবে চিনেন না। বাড়ির ম্যানেজার সোহেল পারভেজ
    বিস্তারিত বলতে পারবেন বলে জানান তিনি।\nএ বিষয়ে সোহেল পারভেজ জানান, আয়েশা সিদ্দিকার নামে এখানে একটি ফ্ল্যাট আছে। তবে তিনি কখনো এখানে আসেন না।
    এটি ভাড়া দেওয়া আছে।\nধানমন্ডি ১২/এ নম্বর রোডের ৬৯ নম্বর বাড়িতে রয়েছে একটি বিলাসবহুল ফ্ল্যাট। শুক্রবার দুপুরে ওই বাড়িতে যাওয়া হলে ভেতরে প্রবেশের অনুমতি
    মেলেনি। তবে নিজের নাম প্রকাশ না করার শর্তে বাড়ির একজন নিরাপত্তাকর্মী জানান, ধানমন্ডির ১২-এ রোডের ৬৯ নম্বর বাড়ির দ্বিতীয় তলার পুরো ফ্লোরটি সাবেক ডিএমপি
    কমিশনার আছাদুজ্জামান মিয়া কিনেছেন। তবে এটি তার শ্যালকের নামে।\nওই ভবনের তৃতীয় তলার ফ্ল্যাটটি চট্টগ্রাম মেট্রোপলিটন পুলিশের (সিএমপি) সাবেক কমিশনার
    ইকবাল বাহারের। এ বিষয়ে পুলিশ সদর দপ্তরের ডিআইজি কৃষ্ণপদ রায় বলেন, ‘ইকবাল বাহার হলেন আছাদুজ্জামান মিয়ার খুবই ঘনিষ্ঠ। তাই তারা দুজন একই ভবনে
    থাকতেন। আমিও একাধিকবার সেখানে গিয়েছি। আছাদুজ্জামান মিয়া কমিশনার থাকা অবস্থায় ওই ভবনে থাকতেন।’\nশুক্রবার দুপুর আড়াইটায় ইস্কাটন গার্ডেন ১৩/এ
    প্রিয়নীড়ে গিয়ে জানা যায়, সেখানে আছাদুজ্জামানের স্ত্রীর নামে একটি ফ্ল্যাট রয়েছে। বিস্তারিত জানতে চাইলে নিরাপত্তাকর্মী আব্দুস সালাম ও শাহ আলম প্রতিবেদককে
    বলেন, ‘আমরা এখানে নতুন এসেছি, তাই তেমন কিছু জানি না।’\nভবনের ম্যানেজার আজাদ আহমেদ জানান, ১৪ তলা এই ভবনে ৪০টি ফ্ল্যাট আছে। বেশিরভাগ ফ্ল্যাটই
    ২১৩৩ বর্গফুটের। ভবনের ১১ তলায় আছাদুজ্জমানের স্ত্রী আফরোজা জামানের একটি ফ্ল্যাট আছে। তবে সেখানে তিনি থাকেন না। ফ্ল্যাটটি ভাড়া দেওয়া আছে। অভ্যর্থনাকারী
    আবু বকর প্রতি মাসে ভাড়া তুলে আছাদুজ্জামানের কাছে দিয়ে আসেন। ভাড়া বকেয়া পড়লে বা কোনো সমস্যা হলে আমি নিজে স্যারের সঙ্গে (আছাদুজ্জমান) যোগাযোগ
    করেন বলে জানান তিনি।\nখোঁজ নিয়ে জানা যায়, নিকুঞ্জ-১ এর ৮/এ রোডের ৬ নম্বর বাড়িটি আছাদুজ্জামানের ছোট ছেলে আসিফ মাহাদীনের নামে। শুক্রবার বিকালে
    সেখানে যাওয়া হলে বাড়িটি ভেতর থেকে বন্ধ পাওয়া যায়। বেশ কয়েকবার কলিংবেল টিপেও সাড়া পাওয়া যাচ্ছিল না। একপর্যায়ে পাশের চার নম্বর বাড়ির গাড়িচালকের
    সঙ্গে কথা হচ্ছিল এই প্রতিবেদকের। ওই গাড়িচালক জানান, আছাদুজ্জামান সপরিবারে এই বাড়িতে থাকতেন। সরকার পতনের পর তিনি বাড়ি ছেড়ে পালিয়ে গেছেন।
    অনুসন্ধানে আরও জানা যায়, এ ছাড়া বসুন্ধরা আবাসিক এলাকার এল ব্লকের ১ নম্বর রোডের ১৬৬ এবং ১৬৭ নম্বরে ১০ কাঠার ওপর ৬ তলাবিশিষ্ট আলিশান একটি বাড়ি
    আছাদুজ্জামানের স্ত্রী আফরোজা জামানের নামে। পূর্বাচলের নিউ টাউনের ১ নম্বর সেক্টরের ৪০৬/বি নম্বর রোডে ১০ কাঠা জমি রয়েছে আছাদুজ্জামান মিয়ার নামে। ওই জমিতে
     গাড়ি রাখার শেড বানিয়ে রাখা হয়েছে। পূর্বাচলের সেক্টর ৪, রোড ১০৮-এ ৫৩ নম্বর প্লটটি আছাদুজ্জামানের স্ত্রীর নামে ছিল। ৫ কাঠার এই প্লটটি বিক্রি করে দেওয়া হয়েছে।
     আফতাবনগরে ৩ নম্বর সেক্টরে রয়েছে ২১ কাঠা জমি। সেখানে নিজের নামে ১০ কাঠা ও আত্মীয়স্বজনদের নামে রয়েছে বাকি ১১ কাঠা জমি।\nআছাদুজ্জামান
     মিয়ার স্ত্রী আফরোজা জামানের নামে ঢাকা ছাড়াও ফরিদপুর ও নারায়ণগঞ্জে বিপুল সম্পদ রয়েছে। ২০১৮ সালে তিনি রাজউক থেকে বিশেষ কোটায় একটি প্লট বরাদ্দ
     পান। অথচ রাজউকের নীতিমালা অনুযায়ী, স্বামী-স্ত্রী উভয়ের প্লট বরাদ্দ পাওয়ার সুযোগ নেই।\nজানা গেছে, গাজীপুরের কালীগঞ্জ উপজেলার চাঁদখোলা মৌজায় আফরোজা
     জামানের নামে ৬৭ শতাংশ জমি রয়েছে। ২০১৭ সালে এই জমি কেনা হয়। ওই মৌজায় তার নামে ২০১৯ সালের ৫ ফেব্রুয়ারি কেনা হয় আরও ৩৯ শতাংশ জমি। একই নামে
     ২০২০ সালে জোয়ার সাহারা মৌজায় কেনা হয় ১৫ কাঠা জমি। ওই বছর গাজীপুরের চাঁদখোলা মৌজায় ৩১ শতক জমি ক্রয় করেন আফরোজা। আফরোজা ২০১৮ সালে
     নারায়ণগঞ্জের রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ২৮ একর জমি কেনেন। ওই বছর একই মৌজায় আরও ৩২ শতক জমি কেনেন তিনি। ওই বছরই
     রূপগঞ্জের কৈয়ামসাইল-কায়েতপাড়া মৌজায় দশমিক ৬০ একর জমি তার নামে কেনা হয়। পরে তা বিক্রি করে দেওয়া হয়। ২০১৯ সালে কৈয়ামসাইল-কায়েতপাড়া মৌজায়
     দশমিক ৫৭ একর জমির পাওয়ার অব অ্যাটর্নি পান আছাদুজ্জামানের স্ত্রী। এরপর ওই জমি বিক্রিও করেন।\nঅনুসন্ধানে আছাদুজ্জামান মিয়ার পরিবারের সদস্যদের মালিকানার
     দুটি কোম্পানির খোঁজ পাওয়া গেছে। এর মধ্যে একটি হলো মৌমিতা ট্রান্সপোর্ট লিমিটেড। এর চেয়ারম্যান আছাদুজ্জামানের স্ত্রী আফরোজা। আছাদুজ্জামান ডিএমপি কমিশনার
     থাকাকালীন রাজধানীর রুট পারমিট কমিটির প্রধান ছিলেন। ওই সময় মৌমিতা পরিবহণকে রুট পারমিট দেওয়া হয়। মৌমিতা ট্রান্সপোর্ট লিমিটেডের ভাইস চেয়ারম্যান হারিসুর
     রহমান সোহান হলেন আছাদুজ্জামানের শ্যালক। সোহানের নামে রাজধানীর নিউমার্কেটে আছে স্বর্ণের দোকান।\nআরও জানা যায়, শেপিয়ার্ড কনসোর্টিয়াম লিমিটেড নামে
     আরেকটি কোম্পানির চেয়ারম্যান আফরোজা জামান। এই কোম্পানির পরিচালক আছাদুজ্জামানের বড় ছেলে আসিফ শাহাদাত। আছাদুজ্জামানের শ্যালক নূর আলম ওরফে
     মিলনের নামে গাজীপুরের শ্রীপুরে দেড় একর জমি রয়েছে। ভাগনে কলমের নামেও গাজীপুরে জমি আছে দেড় একর।\nএদিকে আছাদুজ্জামান মিয়ার অবৈধ সম্পদের
     অনুসন্ধান শুরু করেছে দুদক। সংস্থাটির সচিব খোরশেদা ইয়াসমীন গণমাধ্যমকে বলেন, আছাদুজ্জামান মিয়ার বিরুদ্ধে বিভিন্ন অনিয়ম ও দুর্নীতির মাধ্যমে কোটি কোটি
     টাকার অবৈধ সম্পদ অর্জনের অভিযোগ এসেছে। এই অভিযোগ অনুসন্ধানের সিদ্ধান্ত গৃহীত হয়েছে বলে জানান তিনি।\nআওয়ামী লীগ সরকারের পতনের কয়েকদিন আগে
     আছাদুজ্জামান মিয়া জানিয়েছিলেন, তার এবং পরিবারের সদস্যদের কোনো অবৈধ সম্পদ নেই। যেসব সম্পদ আছে সবই আয়কর বিবরণীতে উল্লেখ করা আছে। সরকারের
     কোনো সংস্থা যদি এসব সম্পদের বিষয়ে অনুসন্ধান চালায় তাহলে তিনি ও তার পরিবারের সদস্যরা ওই সংস্থাকে সহযোগিতা করবেন।'
"""

# Generate the summary for the custom input text
generated_summary = generate_summary(custom_text)

# Print the original text and its generated summary
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  ঢাকা মেট্রোপলিটন পুলিশের (ডিএমপি) সাবেক কমিশনার আছাদুজ্জামান মিয়া রীতিমতো গড়েছেন বিপুল সম্পত্তি। তার গাড়ি, বাড়ি, প্লট এবং ফ্ল্যাট-কী নেই। অনুসন্ধানে এসব তথ্য উঠে এসেছে।

# %%
custom_text2 = """
বাংলাদেশের অর্থনৈতিক অবস্থা উন্নতির দিকে ধাবিত হচ্ছে, বিশেষ করে গত কয়েক বছরে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
অর্থনীতিবিদরা মনে করছেন, এই অগ্রগতি ধরে রাখতে পারলে বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার অন্যতম শক্তিশালী অর্থনীতিতে পরিণত হতে পারে।
"""

generated_summary = generate_summary(custom_text2)
print("\nGenerated Summary:\n", generated_summary)
# Out:
# Generated Summary:
#  বাংলাদেশের অর্থনীতি দক্ষিণ এশিয়ার সবচেয়ে শক্তিশালী দেশগুলোর একটি হিসেবে পরিণত হতে পারে বলে মনে করছেন অর্থনৈতিক বিশ্লেষকরা। এর মধ্যে রপ্তানি খাতে ব্যাপক অগ্রগতি হয়েছে।
